# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newsapi import NewsApiClient
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\jakek\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Create a newsapi client
from newsapi import NewsApiClient
load_dotenv()
newsapi = NewsApiClient(api_key=os.environ["NEWS_API_KEY"])

# %%
# Fetch the Bitcoin news articles
bitcoin_news = newsapi.get_everything(
    q="Bitcoin",
    language="en",
    page_size=100, # the number of results to return per page
    sort_by="relevancy"
)

# Print total articles
print(f"Total articles about Bitcoin: {bitcoin_news['totalResults']}")

# Show the total number of Bitcoin news
bitcoin_news["totalResults"]

# Show sample article
bitcoin_news["articles"]
# Out:
# Total articles about Bitcoin: 8478
# [{'source': {'id': None, 'name': 'Lifehacker.com'},
#   'author': 'Jeff Somers',
#   'title': 'Is the Crypto Bubble Going to Burst?',
#   'description': 'Even if you aren’t paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted last week, with the total value of the market tumbling from a high of $3 trillion last year to about $1.5 trillion in a matter of days…',
#   'url': 'https://lifehacker.com/is-the-crypto-bubble-going-to-burst-1848475768',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/976a59b09e0e681e692bd7517498e3f2.jpg',
#   'publishedAt': '2022-02-09T16:00:00Z',
#   'content': 'Even if you arent paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted last week, with the total value of the market tumbling from a high of $3 tr… [+4782 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Gian M. Volpicelli',
#   'title': 'As Kazakhstan Descends into Chaos, Crypto Miners Are at a Loss',
#   'description': 'The central Asian country became No. 2 in the world for Bitcoin mining. But political turmoil and power cuts have hit hard, and the future looks bleak.',
#   'url': 'https://www.wired.com/story/kazakhstan-cryptocurrency-mining-unrest-energy/',
#   'urlToImage': 'https://media.wired.com/photos/61de2d453e654a13e9a16ef0/191:100/w_1280,c_limit/Business_Kazakhstan-2HDE52K.jpg',
#   'publishedAt': '2022-01-12T12:00:00Z',
#   'content': 'When Denis Rusinovich set up cryptocurrency mining company Maveric Group in Kazakhstan in 2017, he thought he had hit the jackpot. Next door to China and Russia, the country had everything a Bitcoin … [+4140 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Mitchell Clark',
#   'title': 'The International Monetary Fund tells El Salvador it shouldn’t use Bitcoin as legal tender',
#   'description': 'The International Monetary Fund’s executive directors have recommended to El Salvador that it should narrow the scope of its Bitcoin law, making it so that the cryptocurrency is no longer legal tender in the country.',
#   'url': 'https://www.theverge.com/2022/1/25/22901374/el-salvador-bitcoin-international-monetary-fund-crypto',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/altkKN7BnaLUpbAVPi6j4xmC2Ug=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/13546110/acastro_181126_1777_bitcoin_0001.jpg',
#   'publishedAt': '2022-01-25T22:11:14Z',
#   'content': 'El Salvador introduced Bitcoin as a legal tender alongside the US dollar in 2021. | Illustration by Alex Castro / The Verge\r\n\n \n\n The International Monetary Fund’s executive board has recommended El … [+2691 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jon Porter',
#   'title': 'Jack Dorsey’s Block is working to make Bitcoin mining easier',
#   'description': 'Block is working on building an “open Bitcoin mining system,” its CEO Jack Dorsey has announced. The company’s goals for the system are for it to be easily available, reliable, and relatively power efficient.',
#   'url': 'https://www.theverge.com/2022/1/14/22883500/jack-dorsey-block-bitcoin-mining-system-open-source-mainstream',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/NE548fVufAlHoBliurOdnG-lfuw=/0x215:3000x1786/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23168502/1321753348.jpg',
#   'publishedAt': '2022-01-14T13:46:28Z',
#   'content': 'Were officially building an open Bitcoin mining system\r\nPhoto by Joe Raedle/Getty Images\r\nBlock, the payment company formerly known as Square, is working on building an open Bitcoin mining system, it… [+2078 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Corin Faife',
#   'title': 'DeepDotWeb operator sentenced to eight years for money laundering',
#   'description': 'The operator of DeepDotWeb, a site that indexed dark net marketplaces accessible through Tor browser, was sentenced to eight years after pleading guilty to money laundering using Bitcoin.',
#   'url': 'https://www.theverge.com/2022/1/27/22904803/deepdotweb-operator-sentenced-money-laundering-bitcoin-darknet-fbi',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/mde_l3lUC4muDPEFG7LYrUz0O3g=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/8921023/acastro_bitcoin_2.jpg',
#   'publishedAt': '2022-01-27T18:16:57Z',
#   'content': 'Israeli national Tal Prihar pled guilty to routing money from kickbacks through Bitcoin and shell companies \r\nIllustration by Alex Castro / The Verge\r\nIn the culmination of a two-year legal process, … [+1448 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Corin Faife',
#   'title': 'Crypto.com admits over $30 million stolen by hackers',
#   'description': 'Cryptocurrency exchange Crypto.com has said that $15 million in ethereum and $18 million in bitcoin were stolen by hackers in a security breach',
#   'url': 'https://www.theverge.com/2022/1/20/22892958/crypto-com-exchange-hack-bitcoin-ethereum-security',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/mde_l3lUC4muDPEFG7LYrUz0O3g=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/8921023/acastro_bitcoin_2.jpg',
#   'publishedAt': '2022-01-20T13:23:31Z',
#   'content': 'In a new blog post the company said that 4,836 ETH and 443 bitcoin were taken\r\nIllustration by Alex Castro / The Verge\r\nIn a blog post published in the early hours of Thursday morning, cryptocurrency… [+2004 chars]'},
#  {'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Kris Holt',
#   'title': 'Netflix is already making a docuseries about the alleged billion-dollar bitcoin launderers',
#   'description': 'Netflix\r\n is making a docuseries about one of the worst rappers of all time\r\n. Coincidentally, Heather "Razzlekhan" Morgan and her husband, Ilya Lichtenstein, were charged this week with conspiring to launder 119,754 bitcoin, which was stolen in the 2016 hack…',
#   'url': 'https://www.engadget.com/netflix-billion-dollar-bitcoin-launderers-192241113.html',
#   'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2022-02/74510970-89d5-11ec-bfaf-d4f39cae5191',
#   'publishedAt': '2022-02-11T19:22:41Z',
#   'content': 'Netflix\r\n is making a docuseries about one of the worst rappers of all time\r\n. Coincidentally, Heather "Razzlekhan" Morgan and her husband, Ilya Lichtenstein, were charged this week with conspiring t… [+1432 chars]'},
#  {'source': {'id': None, 'name': 'Blogspot.com'},
#   'author': 'noreply@blogger.com (Unknown)',
#   'title': 'Bitcoin Extends Slide, Has Fallen More Than 50% From Record High',
#   'description': 'Bitcoin, the largest digital asset, extended its decline Saturday, and has now shed more than 50% from its record high in November.Bitcoin’s decline since hitting the record has wiped out more than $600 billion in market value, and over $1 trillion has been l…',
#   'url': 'https://techncruncher.blogspot.com/2022/01/bitcoin-extends-slide-has-fallen-more.html',
#   'urlToImage': 'https://blogger.googleusercontent.com/img/a/AVvXsEhX63nKoO0bHPlhUmotmBnAoeop0qBhuBYbRRw7FyK-ryX64_wAoLezFw3iJgY4g43RT4MEGA0vlqNqFd2OWXghAxs0XLq7BNMreTsT1sgd3z-WYsXvhzYq5EzDcA-Erbu3FwT119zR-UNF-vISiwbNtqHMRYl7_lWt6evRK1xWIazcvKx40HKJ5SdiAw=w1200-h630-p-k-no-nu',
#   'publishedAt': '2022-01-22T13:35:00Z',
#   'content': 'Bitcoin, the largest digital asset, extended its decline Saturday, and has now shed more than 50% from its record high in November.Bitcoin’s decline since hitting the record has wiped out more than $… [+567 chars]'},
#  {'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Mariella Moon',
#   'title': "Block is officially building an 'open Bitcoin mining system,' says founder Jack Dorsey",
#   'description': 'Block founder Jack Dorsey has announced on Twitter that the company is officially building an open bitcoin mining system. Dorsey first announced in October last year that the digital payments provider, then known as Square, was considering working on the proj…',
#   'url': 'https://www.engadget.com/jack-dorseys-block-is-officially-building-an-open-bitcoin-mining-system-114033482.html',
#   'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-12/b08eca30-67a7-11ec-bfef-a5351ba20ef6',
#   'publishedAt': '2022-01-14T11:40:33Z',
#   'content': 'Block founder Jack Dorsey has announced on Twitter that the company is officially building an open bitcoin mining system. Dorsey first announced in October last year that the digital payments provide… [+1584 chars]'},
#  {'source': {'id': None, 'name': 'Blogspot.com'},
#   'author': 'noreply@blogger.com (Unknown)',
#   'title': 'Musk says Tesla to accept dogecoin for merchandise',
#   'description': '<table><tr><td></td></tr><tr><td>\xa0Representation of cryptocurrency Dogecoin is seen in this illustration taken November 29, 2021. REUTERS/Dado Ruvic/Illustration/File Photo</td></tr>\r\n</table>Tesla Inc (TSLA.O) will accept the meme-based cryptocurrency dogeco…',
#   'url': 'https://techncruncher.blogspot.com/2022/01/musk-says-tesla-to-accept-dogecoin-for.html',
#   'urlToImage': 'https://blogger.googleusercontent.com/img/a/AVvXsEiAHi2o-pAdNQNqbU6eVnDtHVY2HvIYdHuBHFQXpjzRRvUkNNNjSD8rJIH_TmYn8--wpME7gw7bhfJ6KoISJSNOJQLfYqr-HZT02wXpVXeg0Ar9yGLKD_ZNbToLt0-vBjvldJdotQOlbaWzlZonZIIINp6eG1v0xyMZdNVTVX4hq23Qkx6XGF9NIurkfw=w1200-h630-p-k-no-nu',
#   'publishedAt': '2022-01-14T14:14:00Z',
#   'content': 'Tesla Inc (TSLA.O) will accept the meme-based cryptocurrency dogecoin as payment for its products such as the "Giga Texas" belt buckle and mini\xa0 electric vehicle models, CEO Elon Musk said on Friday … [+1482 chars]'},
#  {'source': {'id': None, 'name': 'New York Times'},
#   'author': 'Dana Rubinstein, Jonah E. Bromwich and Jeffery C. Mays',
#   'title': 'Eric Adams Is Taking His First Paycheck in Crypto',
#   'description': 'Mr. Adams, who wants New York City to become the global capital for cryptocurrency, will have his paycheck converted into Bitcoin and Ethereum.',
#   'url': 'https://www.nytimes.com/2022/01/20/nyregion/eric-adams-bitcoin-cryptocurrency.html',
#   'urlToImage': 'https://static01.nyt.com/images/2022/01/20/nyregion/20adams-crypto01/20adams-crypto01-facebookJumbo.jpg',
#   'publishedAt': '2022-01-20T19:54:48Z',
#   'content': 'On some level, the new mayor is simply employing an age-old political strategy: making overtures to the business community. Fintech is a growing field in New York City, and blockchain-based companies… [+1562 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Gian M. Volpicelli',
#   'title': 'Gibraltar Could Launch the World’s First Crypto Stock Exchange',
#   'description': '“The Rock” hopes a new stock exchange will attract crypto millionaires who want to avoid hefty taxes.',
#   'url': 'https://www.wired.com/story/gibraltar-crypto-exchange/',
#   'urlToImage': 'https://media.wired.com/photos/61f0b4bf03f9ae99229f47d4/191:100/w_1280,c_limit/Business_Gibraltar-1208348908.jpg',
#   'publishedAt': '2022-01-26T12:00:00Z',
#   'content': 'British entrepreneur and financier Richard ODell Poulden hopes that his new venture will relieve the plight of an underserved cohort: Bitcoin billionaires who want to buy a house.\r\nIn October, Poulde… [+3364 chars]'},
#  {'source': {'id': None, 'name': 'Blogspot.com'},
#   'author': 'noreply@blogger.com (Unknown)',
#   'title': 'Russian c.bank proposes banning cryptocurrencies, crypto mining',
#   'description': "<table><tr><td></td></tr><tr><td>Representations of virtual cryptocurrencies are seen in this illustration taken November 28, 2021. REUTERS/Dado Ruvic/Illustration/File Photo</td></tr>\r\n</table>Russia's central bank on Thursday proposed banning the use and mi…",
#   'url': 'https://techncruncher.blogspot.com/2022/01/russian-cbank-proposes-banning.html',
#   'urlToImage': 'https://blogger.googleusercontent.com/img/a/AVvXsEh8Ab2fniYX1LMiTt-SPNcljyB-NxzIH1dlQTxEvcspfJZA-dwAY1rGM3kB4TV9RsJFUZg-x_0n7tfSr8j-WBwrBpsKE543Zdyd75jKXHVcGwSjeuqaueLN4BpkzkxjM3ik7yYdc9yCr_qRRy32QlvV9DtvFZefdtdqiYPTvpZHgVUVFKfbADao2NjVIQ=w1200-h630-p-k-no-nu',
#   'publishedAt': '2022-01-20T12:56:00Z',
#   'content': "Russia's central bank on Thursday proposed banning the use and mining of cryptocurrencies\xa0on Russian territory, citing threats to financial stability, citizens' wellbeing and its monetary policy sove… [+2149 chars]"},
#  {'source': {'id': None, 'name': 'New York Times'},
#   'author': 'Katie Benner',
#   'title': 'Justice Dept. Seizes $3.6 Billion in Bitcoin and Arrests Married Couple',
#   'description': 'The couple were accused of conspiring to launder Bitcoin that had been stolen in 2016 from Hong Kong-based Bitfinex, one of the world’s largest virtual currency exchanges.',
#   'url': 'https://www.nytimes.com/2022/02/08/us/politics/ilya-lichtenstein-heather-morgan-bitcoin-laundering.html',
#   'urlToImage': 'https://static01.nyt.com/images/2022/02/08/us/politics/08dc-justice-1/merlin_199575684_cb549cca-76dd-4ad4-8fe9-a5f54d1024b9-facebookJumbo.jpg',
#   'publishedAt': '2022-02-08T23:37:54Z',
#   'content': 'Over the last five years, about 25,000 of those Bitcoin were transferred out of Mr. Lichtensteins wallet using a complicated series of transactions meant to obscure that the currency had been stolen … [+2506 chars]'},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'https://www.facebook.com/bbcnews',
#   'title': 'IMF urges El Salvador to remove Bitcoin as legal tender',
#   'description': 'Officials say the decision poses risks to financial stability and consumer protection in the country.',
#   'url': 'https://www.bbc.co.uk/news/world-latin-america-60135552',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/5D55/production/_118839832_bitcoinstorereuters.jpg',
#   'publishedAt': '2022-01-26T04:54:14Z',
#   'content': 'Image caption, Bitcoin is accepted everywhere for goods and services in El Salvador, alongside the US dollar\r\nThe International Monetary Fund (IMF) has urged El Salvador to reverse its decision to ma… [+1846 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': 'Reuters Staff',
#   'title': "U.S. SEC rejects Fidelity's Wise Origin spot bitcoin ETF - Reuters.com",
#   'description': "The U.S. Securities and Exchange Commission on Thursday rejected a proposal to offer spot bitcoin exchange-traded funds (ETF) from Fidelity's Wise Origin Bitcoin Trust.",
#   'url': 'https://www.reuters.com/article/crypto-currency-sec-etf-idUSL4N2U62Z0',
#   'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#   'publishedAt': '2022-01-27T15:19:00Z',
#   'content': 'By Reuters Staff\r\nJan 26 (Reuters) - The U.S. Securities and Exchange Commission on Thursday rejected a proposal to offer spot bitcoin exchange-traded funds (ETF) from Fidelitys Wise Origin Bitcoin T… [+202 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'hmalik@insider.com (Hamza Fareed Malik)',
#   'title': 'Jack Dorsey says Block is building a bitcoin mining system so that anyone can easily buy a rig',
#   'description': 'Block is officially building a bitcoin mining system to make mining bitcoin "more distributed and efficient."',
#   'url': 'https://markets.businessinsider.com/news/currencies/block-bitcoin-mining-jack-dorsey-rig-crypto-open-anyone-buy-2022-1',
#   'urlToImage': 'https://images2.markets.businessinsider.com/61e16983c5e27c00185b8d80?format=jpeg',
#   'publishedAt': '2022-01-14T12:34:09Z',
#   'content': 'Jack Dorsey onstage at a bitcoin convention in June.Joe Raedle/Getty Images\r\nBlock is going ahead with building a bitcoin mining system that will be open to individuals and businesses worldwide, its … [+2459 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Jody Serrano',
#   'title': 'It Only Took 3 Days for Netflix to Order a Docuseries on the Bonnie and Clyde of the Crypto World',
#   'description': 'The news of one of the biggest money laundering schemes in history captivated the world on Tuesday, not so much because of the crime—which involved $4.5 billion in bitcoin and is, yeah, a big deal—but rather because of the couple accused of carrying it out. T…',
#   'url': 'https://gizmodo.com/netflix-docuseries-ilya-dutch-lichtenstein-heather-mo-1848527088',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/4102a58766b858d04921451038439041.jpg',
#   'publishedAt': '2022-02-12T02:49:00Z',
#   'content': 'The news of one of the biggest money laundering schemes in history captivated the world on Tuesday, not so much because of the crimewhich involved $4.5 billion in bitcoin and is, yeah, a big dealbut … [+1948 chars]'},
#  {'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Igor Bonifacic',
#   'title': 'Robinhood opens cryptocurrency wallet to beta testers',
#   'description': 'Back in September\r\n, Robinhood announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availability ahead of a full-scale release. If you joined the wait…',
#   'url': 'https://www.engadget.com/robinhood-cryptocurrency-wallet-beta-225721593.html',
#   'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-09/5035fef0-1bd6-11ec-b7e5-a610838e0b98',
#   'publishedAt': '2022-01-21T22:57:21Z',
#   'content': 'Back in September\r\n, Robinhood announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availa… [+1069 chars]'},
#  {'source': {'id': None, 'name': 'New York Times'},
#   'author': 'Ed Shanahan and Jesus Jiménez',
#   'title': 'Who are Ilya Lichtenstein and Heather Morgan, Charged in Bitcoin Case?',
#   'description': 'Before being accused in a major cryptocurrency conspiracy, Ilya Lichtenstein and Heather Morgan shared advice, ideas and amateur rap videos online.',
#   'url': 'https://www.nytimes.com/2022/02/08/nyregion/ilya-lichtenstein-heather-morgan.html',
#   'urlToImage': 'https://static01.nyt.com/images/2022/02/08/nyregion/08cryptocouple/merlin_199575687_86d8e964-7e6c-41cf-945a-0eb6d392f7cf-facebookJumbo.jpg',
#   'publishedAt': '2022-02-09T02:27:29Z',
#   'content': 'In one 2020 article for the magazine, she explored how to protect your business as cybercriminals and fraudsters are taking advantage of disruptions caused by the pandemic.\r\nFor Inc.s entrepreneurial… [+1705 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Matt Novak',
#   'title': 'Crypto.com Finally Acknowledges $34 Million Stolen by Hackers',
#   'description': 'Trading platform Crypto.com lost about $34 million worth of cryptocurrency in a hack on Monday, according to a new blog post by the company published overnight. The company had previously declined to say much about the hack, which forced users to stop withdra…',
#   'url': 'https://gizmodo.com/crypto-com-finally-acknowledges-34-million-stolen-by-h-1848389819',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/3c7e7ff30b167a88b03f3ef59220cd22.jpg',
#   'publishedAt': '2022-01-20T12:00:00Z',
#   'content': 'Trading platform Crypto.com lost about $34 million worth of cryptocurrency in a hack on Monday, according to a new blog post by the company published overnight. The company had previously declined to… [+2933 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Mack DeGeurin',
#   'title': 'EU Regulator Wants to Ban Proof of Work Crypto Mining to Avoid Climate Disaster',
#   'description': 'One of the European Union’s top regulators has a new proposal for reducing cryptocurrency’s carbon footprint: ban proof of work mining. The proposed prohibition, suggested by European Securities and Markets Authority Vice Chair Erik Thedéen during a Financial…',
#   'url': 'https://gizmodo.com/european-union-regulator-proof-of-work-bitcoin-ethereum-1848384679',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/e347ce1038984213dcf95a7a9142c961.jpg',
#   'publishedAt': '2022-01-19T17:55:00Z',
#   'content': 'One of the European Unions top regulators has a new proposal for reducing cryptocurrencys carbon footprint: ban proof of work mining. The proposed prohibition, suggested by European Securities and Ma… [+3602 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Omar L. Gallaga',
#   'title': 'Playing With Crypto? You’ll Need a Wallet (or Several)',
#   'description': 'Buying and selling NFTs or transferring digital currency is going to require a little leap of faith. Here’s how to get started.',
#   'url': 'https://www.wired.com/story/how-to-choose-set-up-crypto-wallet/',
#   'urlToImage': 'https://media.wired.com/photos/620415899266d5d11c07b346/191:100/w_1280,c_limit/Gear-Coinbase-App-Screens.jpg',
#   'publishedAt': '2022-02-10T14:00:00Z',
#   'content': "If people who buy cryptocurrencies intended only to hold on to them as speculative investments, there'd be no real need for crypto wallets. Exchanges and online brokerages that convert dollars to, sa… [+3031 chars]"},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'CRYPTOVERSE-Bitcoin squeezes smaller rivals to its crown - Reuters',
#   'description': 'Bitcoin is beginning to reassert its dominance over challengers to its cryptocurrency crown.',
#   'url': 'https://www.reuters.com/markets/europe/cryptoverse-bitcoin-squeezes-smaller-rivals-its-crown-2022-02-01/',
#   'urlToImage': 'https://www.reuters.com/resizer/trzf0WaGaNyLC7bG_gRXhD2h0Ag=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/SLSYKLM3IJPZNNH5EMCYLZA2F4.jpg',
#   'publishedAt': '2022-02-01T06:00:00Z',
#   'content': 'Feb 1 (Reuters) - Bitcoin is beginning to reassert its dominance over challengers to its cryptocurrency crown.\r\nThe original digital coin was assailed by thousands of new "altcoin" competitors in 202… [+3972 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Bitcoin surges 8.82% to $40611 - Reuters',
#   'description': 'Bitcoin surged 8.82% to $40,611.4 at 2202 GMT on Friday, adding $3,291.29 to its previous close.',
#   'url': 'https://www.reuters.com/technology/bitcoin-surges-882-40611-2022-02-04/',
#   'urlToImage': 'https://www.reuters.com/resizer/iF8DKAnETeNHBq1q1qRRQFe4oZo=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/5KHWYF53XBNEFLDIU4B47BZYQE.jpg',
#   'publishedAt': '2022-02-04T22:27:00Z',
#   'content': "Feb 4 (Reuters) - Bitcoin surged 8.82% to $40,611.4 at 2202 GMT on Friday, adding $3,291.29 to its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is up 23.2% from the ye… [+321 chars]"},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Bitcoin falls 9.3% to $36955 - Reuters',
#   'description': 'Bitcoin dropped 9.28% to $36,955.03 at 22:02 GMT on Friday, losing $3,781.02 from its previous close.',
#   'url': 'https://www.reuters.com/technology/bitcoin-falls-93-36955-2022-01-21/',
#   'urlToImage': 'https://www.reuters.com/resizer/dAgPtOWZKLDrKS2Jwdrqn294sU0=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/HJLMCJEIPNKXBEOQ6T3SCMFCEM.jpg',
#   'publishedAt': '2022-01-21T23:30:00Z',
#   'content': 'A representation of virtual currency Bitcoin is seen in front of a stock graph in this illustration taken January 8, 2021. REUTERS/Dado Ruvic/File PhotoJan 21 (Reuters) - Bitcoin dropped 9.28% to $36… [+508 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Cryptocurrency finds itself in the sights of robust regulation - Reuters',
#   'description': "Depending upon who you talk to, cryptocurrency is all the rage, a Ponzi scheme or yet another energy-consuming scourge on the environment. (See tweets by Elon Musk from mid-May 2021, citing the environmental impact of bitcoin transactions for Tesla's decision…",
#   'url': 'https://www.reuters.com/legal/transactional/cryptocurrency-finds-itself-sights-robust-regulation-2022-01-24/',
#   'urlToImage': 'https://www.reuters.com/resizer/mDjQYBnitP_a_uKIL8Kh_Hz5Iww=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OZIEFAHPYZNTBK2DBAT7THTKCQ.jpg',
#   'publishedAt': '2022-01-24T16:17:00Z',
#   'content': 'January 24, 2022 - Depending upon who you talk to, cryptocurrency is all the rage, a Ponzi scheme or yet another energy-consuming scourge on the environment. (See tweets by Elon Musk from mid-May 202… [+10597 chars]'},
#  {'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Kris Holt',
#   'title': 'Spain sets new rules for influencers who promote cryptocurrency',
#   'description': 'Spain is establishing rules related to how influencers, their sponsors and others promote cryptocurrencies. Influencers and other advertisers with more than 100,000 followers in the country must notify the National Securities Market Commission (CNMV) at least…',
#   'url': 'https://www.engadget.com/spain-influencers-cryptocurrency-promotion-rules-advertising-172028187.html',
#   'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-08/920a5870-f891-11eb-89eb-471087e7869f',
#   'publishedAt': '2022-01-18T03:18:28Z',
#   'content': 'Spain is establishing rules related to how influencers, their sponsors and others promote cryptocurrencies. Influencers and other advertisers with more than 100,000 followers in the country must noti… [+1568 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'hrobertson@businessinsider.com (Harry Robertson)',
#   'title': "Anthony Scaramucci says he's not buying the dip in bitcoin as he expects more 'sloppiness' and volatility",
#   'description': 'The bitcoin price is likely to consolidate for a while, SkyBridge Capital CEO Anthony Scaramucci said.',
#   'url': 'https://markets.businessinsider.com/news/currencies/anthony-scaramucci-skybridge-investor-bitcoin-price-outlook-dip-volatility-2022-1',
#   'urlToImage': 'https://images2.markets.businessinsider.com/61e15623c5e27c00185b8b85?format=jpeg',
#   'publishedAt': '2022-01-14T11:22:37Z',
#   'content': "Former Trump White House communications director Anthony Scaramucci is a big bitcoin investor.AP Photo/Pablo Martinez Monsivais, File\r\nSkyBridge Capital CEO Anthony Scaramucci has said he's not buyin… [+2391 chars]"},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'msmash',
#   'title': 'Wikipedia Faces Pressure To Stop Accepting Crypto Donations on Environmental Grounds',
#   'description': 'Wikimedia, the non-profit foundation that runs Wikipedia, is facing internal opposition to its policy of accepting cryptocurrency as a form of donation, primarily for environmental reasons. From a report: A proposal to the foundation from contributor Molly Wh…',
#   'url': 'https://news.slashdot.org/story/22/01/12/1810251/wikipedia-faces-pressure-to-stop-accepting-crypto-donations-on-environmental-grounds',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/wikipedia_64.png',
#   'publishedAt': '2022-01-12T18:11:00Z',
#   'content': 'So a single person wrote a proposal and this is called “internal pressure”? This person has the title of “contributor” of which I know not how high ranking it is.\r\nI do wonder, however, what is the e… [+284 chars]'},
#  {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#   'author': 'The Conversation',
#   'title': 'Is Bitcoin technically a religion? A scholar investigates',
#   'description': 'Read enough about Bitcoin, and you’ll inevitably come across people who refer to the cryptocurrency as a religion. Bloomberg’s Lorcan Roche Kelly called Bitcoin “the first true religion of the 21st century.” Bitcoin promoter Hass McCook has taken to calling h…',
#   'url': 'https://thenextweb.com/news/is-bitcoin-technically-a-religion-a-scholar-investigates',
#   'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F02%2FBitcoin-messiah-priest-religion-religious-leader-hed.jpg&signature=03f2bf1e7030b63c9021d0754a1f1f4a',
#   'publishedAt': '2022-02-05T15:21:31Z',
#   'content': 'Read enough about Bitcoin, and youll inevitably come across people who refer to the cryptocurrency as a religion.\r\nBloombergs Lorcan Roche Kelly called Bitcoin the first true religion of the 21st cen… [+8156 chars]'},
#  {'source': {'id': None, 'name': 'Ctvnews.ca'},
#   'author': 'Diksha Madhok',
#   'title': 'Bitcoin value tumbles almost 50 per cent since record November - CTV News',
#   'description': '<ol><li>Bitcoin value tumbles almost 50 per cent since record November\xa0\xa0CTV News\r\n</li><li>Bitcoin crashes to five-month low as Russia proposes crypto ban\xa0\xa0Yahoo Canada Finance\r\n</li><li>Like ‘The 1929 Crash’—New Crypto Winter Warning As Sell-Off Wipes $1.5 T…',
#   'url': 'https://www.ctvnews.ca/sci-tech/bitcoin-value-tumbles-almost-50-per-cent-since-record-november-1.5750783',
#   'urlToImage': 'https://www.ctvnews.ca/polopoly_fs/1.5750786.1642871612!/httpImage/image.jpg_gen/derivatives/landscape_620/image.jpg',
#   'publishedAt': '2022-01-22T17:14:25Z',
#   'content': "Bitcoin has lost almost half its value since its November high, with cryptocurrency prices continuing to plunge as major economies look to curb their growing popularity.\r\nAnd it's not just Bitcoin, a… [+1912 chars]"},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Bitcoin tumbles to six-month low as Ukraine conflict fears shake markets - Reuters',
#   'description': 'Bitcoin tumbled over 7% on Monday to its lowest in six months, as fears of a Russian attack on Ukraine saw riskier assets worldwide extend their selloff.',
#   'url': 'https://www.reuters.com/business/bitcoin-tumbles-7-lowest-since-july-2022-01-24/',
#   'urlToImage': 'https://www.reuters.com/resizer/vPbgJHv4bdM6a2BUSjmdOw8TDo4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/EKFZDQS2JFIO7GKP7GF2P6E63M.jpg',
#   'publishedAt': '2022-01-24T10:35:00Z',
#   'content': 'LONDON, Jan 24 (Reuters) - Bitcoin tumbled over 7% on Monday to its lowest in six months, as fears of a Russian attack on Ukraine saw riskier assets worldwide extend their selloff.\r\nThe largest crypt… [+1607 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': "CRYPTOVERSE-After bitcoin 'winter', investors hunt risk in virtual worlds - Reuters",
#   'description': 'As bitcoin drifts towards mainstream maturity in 2022, daring crypto investors are eyeing up new sources of explosive action: "altcoins" that power online games and worlds.',
#   'url': 'https://www.reuters.com/markets/europe/cryptoverse-after-bitcoin-winter-investors-hunt-risk-virtual-worlds-2022-02-08/',
#   'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=70',
#   'publishedAt': '2022-02-08T06:00:00Z',
#   'content': 'Feb 8 (Reuters) - As bitcoin drifts towards mainstream maturity in 2022, daring crypto investors are eyeing up new sources of explosive action: "altcoins" that power online games and worlds.\r\nBut, be… [+3923 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Wall St Week Ahead Crypto investors face more uncertainty after rocky start to 2022 - Reuters',
#   'description': 'Investors are bracing for more gyrations in bitcoin and other cryptocurrencies, as worries over a hawkish Federal Reserve threaten to squelch risk appetite across markets.',
#   'url': 'https://www.reuters.com/business/finance/wall-st-week-ahead-crypto-investors-face-more-uncertainty-after-rocky-start-2022-2022-02-11/',
#   'urlToImage': 'https://www.reuters.com/resizer/o-neidYH62soGCDm3MOwoSkkRqc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/AOEOU7DFBRN5ZA32VLFEUPFGKY.jpg',
#   'publishedAt': '2022-02-11T20:11:00Z',
#   'content': 'NEW YORK, Feb 11 (Reuters) - Investors are bracing for more gyrations in bitcoin and other cryptocurrencies, as worries over a hawkish Federal Reserve threaten to squelch risk appetite across markets… [+5024 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'U.S. SEC rejects SkyBridge spot bitcoin ETF in latest veto - Reuters',
#   'description': 'The U.S. Securities and Exchange Commission on Thursday rejected a filing to list and trade a spot bitcoin exchange-traded fund by First Trust Advisors and SkyBridge, the hedge fund founded by former White House communications director Anthony Scaramucci.',
#   'url': 'https://www.reuters.com/legal/litigation/us-sec-rejects-skybridge-spot-bitcoin-etf-latest-veto-2022-01-20/',
#   'urlToImage': 'https://www.reuters.com/resizer/I23Eq0SSTqYJhxj1o5-yOhRlCMU=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/RGBU5C3XOVMIJONZGMT4DMBLL4.jpg',
#   'publishedAt': '2022-01-20T16:37:00Z',
#   'content': 'The seal of the U.S. Securities and Exchange Commission (SEC) is seen at their headquarters in Washington, D.C., U.S., May 12, 2021. Picture taken May 12, 2021. REUTERS/Andrew Kelly<ul><li>\r\nIntercon… [+1650 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Bitcoin skids to six-month low as fears over Ukraine shake markets - Reuters',
#   'description': 'Bitcoin tumbled to its lowest level in six months on Monday as fears of a Russian attack on Ukraine saw riskier assets worldwide extend their sell-off.',
#   'url': 'https://www.reuters.com/business/bitcoin-skids-six-month-low-fears-over-ukraine-shake-markets-2022-01-24/',
#   'urlToImage': 'https://www.reuters.com/resizer/vPbgJHv4bdM6a2BUSjmdOw8TDo4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/EKFZDQS2JFIO7GKP7GF2P6E63M.jpg',
#   'publishedAt': '2022-01-24T17:11:00Z',
#   'content': 'LONDON/NEW YORK, Jan 24 (Reuters) - Bitcoin tumbled to its lowest level in six months on Monday as fears of a Russian attack on Ukraine saw riskier assets worldwide extend their sell-off.\r\nThe larges… [+2280 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Intel launches blockchain chip to tap crypto boom - Reuters',
#   'description': 'Intel Corp on Friday launched a new chip for blockchain applications such as Bitcoin mining and minting NFTs to cash in on the rising usage of cryptocurrencies.',
#   'url': 'https://www.reuters.com/technology/intel-launches-blockchain-chip-tap-crypto-boom-2022-02-11/',
#   'urlToImage': 'https://www.reuters.com/resizer/xofDHdDSZIcvlRX0ucwH1xj5Hv4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/CQCFIUFLXNM7PH4PYYZKNCYNAE.jpg',
#   'publishedAt': '2022-02-11T18:14:00Z',
#   'content': 'Feb 11 (Reuters) - Intel Corp on Friday launched a new chip for blockchain applications such as Bitcoin mining and minting NFTs to cash in on the rising usage of cryptocurrencies.\r\nThe chip will ship… [+1192 chars]'},
#  {'source': {'id': None, 'name': 'Entrepreneur'},
#   'author': 'Chloe Arrojado',
#   'title': "Fears of the Fed's Policy Changes Send Huge Losses in the Cryptocurrency Market",
#   'description': 'Bitcoin is now valued at around half of its November market highs.',
#   'url': 'https://www.entrepreneur.com/article/414714',
#   'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1643039603-shutterstock-1975856621.jpg',
#   'publishedAt': '2022-01-24T15:53:52Z',
#   'content': 'The volatile cryptocurrency market is taking a hit as the Fed is expected to hike interest rates\xa0in an effort to combat inflation.\r\n"Central banks and governments have played a role in jacking up the… [+1302 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': "Kazakhstan's bitcoin 'paradise' may be losing its lustre - Reuters",
#   'description': 'Kazakhstan may no longer be the bitcoin sanctuary it once was, according to some big miners who are looking to leave the global crypto hub following internet shutdowns last week that compounded fears about tightening regulation.',
#   'url': 'https://www.reuters.com/technology/kazakhstans-bitcoin-paradise-may-be-losing-its-lustre-2022-01-14/',
#   'urlToImage': 'https://www.reuters.com/resizer/UnpoLSizXlkol3abG_hEmfrBChw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/74LX3SZAJBMBLMDYEPXYS4SNGU.jpg',
#   'publishedAt': '2022-01-14T13:45:00Z',
#   'content': 'LONDON, Jan 14 (Reuters) - Kazakhstan may no longer be the bitcoin sanctuary it once was, according to some big miners who are looking to leave the global crypto hub following internet shutdowns last… [+4521 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'THE CRYPTOVERSE-Teenage bitcoin throws an interest rate tantrum - Reuters',
#   'description': 'Bitcoin is growing up. The original cryptocurrency turns 13 this year and is showing signs of becoming a more mature financial asset - but watch out for the teenage tantrums.',
#   'url': 'https://www.reuters.com/markets/europe/cryptoverse-teenage-bitcoin-throws-an-interest-rate-tantrum-2022-01-25/',
#   'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=69',
#   'publishedAt': '2022-01-25T06:00:00Z',
#   'content': 'Jan 25 (Reuters) - Bitcoin is growing up. The original cryptocurrency turns 13 this year and is showing signs of becoming a more mature financial asset - but watch out for the teenage tantrums.\r\nThis… [+4681 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': 'Reuters Editorial',
#   'title': 'DOJ touts seizure of $3.6 billion in stolen bitcoin - Reuters',
#   'description': 'The U.S. Justice Department said on Tuesday it has unraveled its biggest-ever cryptocurrency theft, seizing a record-shattering $3.6 billion in bitcoin tied to the 2016 hack of digital currency exchange Bitfinex and arresting a husband-and-wife team on money …',
#   'url': 'https://www.reuters.com/video/watch/idRCV00AQ3S',
#   'urlToImage': 'https://static.reuters.com/resources/r/?d=20220209&i=RCV00AQ3S&r=RCV00AQ3S&t=2',
#   'publishedAt': '2022-02-09T19:10:51Z',
#   'content': 'Posted \r\nThe U.S. Justice Department said on Tuesday it has unraveled its biggest-ever cryptocurrency theft, seizing a record-shattering $3.6 billion in bitcoin tied to the 2016 hack of digital curre… [+87 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Breakingviews - Spending bitcoin is harder than stealing it - Reuters',
#   'description': 'Stealing cryptocurrencies is relatively easy. The hard part is turning the proceeds into cash. That’s the lesson from the arrest on Tuesday of Ilya “Dutch” Lichtenstein and his wife Heather Morgan, an artist and rapper also known as Razzlekahn. The pair face …',
#   'url': 'https://www.reuters.com/breakingviews/spending-bitcoin-is-harder-than-stealing-it-2022-02-09/',
#   'urlToImage': 'https://www.reuters.com/resizer/7X-mbvkBotfYcIUX4Ue2lt5E4yU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/2VIRTR43B5KLBHDBQ6VPS7GEJM.jpg',
#   'publishedAt': '2022-02-09T15:51:00Z',
#   'content': 'NEW YORK, Feb 9 (Reuters Breakingviews) - Stealing cryptocurrencies is relatively easy. The hard part is turning the proceeds into cash. Thats the lesson from the arrest on Tuesday of Ilya Dutch Lich… [+4318 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': 'Rodrigo Campos',
#   'title': "UPDATE 1-IMF urged El Salvador to remove bitcoin's legal tender status - Reuters",
#   'description': 'The International Monetary Fund\'s board "urged" El Salvador to do away with its move to make bitcoin a legal tender, while calling for strict regulation of the country\'s e-wallet.',
#   'url': 'https://www.reuters.com/article/imf-el-salvador-idUSL1N2U524W',
#   'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#   'publishedAt': '2022-01-25T19:47:00Z',
#   'content': '(Adds no comment from El Salvador finance minister, details and background)\r\nJan 25 (Reuters) - The International Monetary Funds board urged El Salvador to do away with its move to make bitcoin a leg… [+1631 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': "Bitcoin investors dig in for long haul in 'staggering' shift - Reuters",
#   'description': 'As bitcoin heads into 2022, a growing cohort of long-term investors is doubling down on its stashes of the cryptocurrency, hoping a December dip was merely a festive blip.',
#   'url': 'https://www.reuters.com/technology/bitcoin-investors-dig-long-haul-staggering-shift-2022-01-17/',
#   'urlToImage': 'https://www.reuters.com/resizer/jlDXNlasTK780EAhRKGYL4nqshI=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/WXIF3O4FUVNW7CDMGSEZXSBTOE.jpg',
#   'publishedAt': '2022-01-17T15:58:00Z',
#   'content': 'Jan 17 (Reuters) - As bitcoin heads into 2022, a growing cohort of long-term investors is doubling down on its stashes of the cryptocurrency, hoping a December dip was merely a festive blip.\r\nSome in… [+3835 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'ndailey@insider.com (Natasha Dailey)',
#   'title': "A year after Elon Musk's Tesla bought bitcoin, here are 3 risks companies take when putting it on their balance sheet, investment strategies says",
#   'description': 'The penalty for losing corporate cash by investing in volatile assets like bitcoin can be "severe," the strategist said.',
#   'url': 'https://markets.businessinsider.com/news/currencies/bitcoin-outlook-3-risks-companies-take-adding-to-balance-sheet-2022-2',
#   'urlToImage': 'https://i.insider.com/61f995d2ef63e10018100fbf?width=1200&format=jpeg',
#   'publishedAt': '2022-02-02T13:55:29Z',
#   'content': 'A year ago on February 8, Tesla revealed it had added $1.5 billion worth of bitcoin to its balance sheet opening itself to three big risks, according to one strategist.\r\nWhen companies like Tesla and… [+2279 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Will Paige)',
#   'title': "Twitter aims for edge in Big Tech's crypto contest with OpenNode investment",
#   'description': "Twitter invested an undisclosed sum in OpenNode's $20 million funding round that valued the Bitcoin payments provider at $220 million.",
#   'url': 'https://www.businessinsider.com/twitter-invests-in-opennode-20-million-funding-round-2022-2',
#   'urlToImage': 'https://i.insider.com/62067cd1e2fe3c0019ea2971?width=1200&format=jpeg',
#   'publishedAt': '2022-02-11T15:12:54Z',
#   'content': "The news:\xa0Tech heavyweight\xa0Twitter\xa0invested an undisclosed sum in\xa0OpenNode's $20 million funding round\xa0that valued the Bitcoin payments provider at $220 million, per CoinDesk.\r\nInsider Intelligence\r\n… [+2696 chars]"},
#  {'source': {'id': None, 'name': 'ReadWrite'},
#   'author': 'Leslie Wilder',
#   'title': 'The Beginner’s Guide to Learning to Trade in Bitcoin',
#   'description': '2021 was a year of significant highs and lows for crypto investors. As the market fluctuates, the curiosity surrounding crypto trading looms large. As a result, it will be worthwhile learning how to trade in Bitcoin. Suppose you are feeling overwhelmed with t…',
#   'url': 'https://readwrite.com/the-beginners-guide-to-learning-to-trade-in-bitcoin/',
#   'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2022/01/Learning-to-Trade-in-Bitcoin.jpg',
#   'publishedAt': '2022-02-11T22:01:00Z',
#   'content': '2021 was a year of significant highs and lows for crypto investors. As the market fluctuates, the curiosity surrounding crypto trading looms large. As a result, it will be worthwhile learning how to … [+5479 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'BeauHD',
#   'title': 'The Crypto Selloff Wiped $7 Billion Off Corporate Balance Sheets',
#   'description': "At least 26 public corporations are holding bitcoin on their balance sheets, according to data compiled by cryptocurrency analytics firm CoinGecko. Since the price of cryptocurrencies began to plummet in November, they've collectively lost nearly $7 billion. …",
#   'url': 'https://slashdot.org/story/22/01/28/093257/the-crypto-selloff-wiped-7-billion-off-corporate-balance-sheets',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#   'publishedAt': '2022-01-28T18:18:00Z',
#   'content': 'The Fine Print: The following comments are owned by whoever posted them. We are not responsible for them in any way.'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'mfox@businessinsider.com (Matthew Fox)',
#   'title': 'MicroStrategy extends 2-day decline to 30% as bitcoin melts down and SEC rejects its crypto accounting',
#   'description': "MicroStrategy has bought 124,391 bitcoin at an average price of $30,159, which is just 10% below bitcoin's current price.",
#   'url': 'https://markets.businessinsider.com/news/stocks/microstrategy-stock-price-bitcoin-selloff-crypto-sec-accounting-saylor-2022-1',
#   'urlToImage': 'https://images2.markets.businessinsider.com/61eeadf8d26530001804553d?format=jpeg',
#   'publishedAt': '2022-01-24T14:48:40Z',
#   'content': 'Michael Saylor, CEO of MicroStrategyJoe Raedle/Getty Images\r\nMicroStrategy extended its two-day decline to 30% on Monday amid a meltdown in bitcoin prices and after the SEC rejected its crypto accoun… [+1611 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'ilee@insider.com (Isabelle Lee)',
#   'title': 'MicroStrategy reported a $146 million impairment charge related to its bitcoin holdings in the 4th quarter',
#   'description': 'The firm bought on Tuesday bought another $25 million of bitcoin at an average price of $37,865 per coin, bringing its total to125,051 bitcoins.',
#   'url': 'https://markets.businessinsider.com/news/currencies/microstrategy-bitcoin-impairment-charge-net-loss-q4-earnings-mstr-2022-2',
#   'urlToImage': 'https://i.insider.com/61fa864b4faa730018ff6744?width=1200&format=jpeg',
#   'publishedAt': '2022-02-02T15:54:02Z',
#   'content': 'MicroStrategy posted a $146.6 million impairment charge related to its bitcoin holdings for the fourth quarter of 2021, rising six-fold compared to the same period last year and resulting in a net lo… [+2808 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'BeauHD',
#   'title': 'El Salvador Angrily Rejects IMF Call To Drop Bitcoin Use',
#   'description': 'The government of El Salvador on Monday rejected a recommendation by the International Monetary Fund to drop Bitcoin as legal tender in the Central American country. ABC News reports: Treasury Minister Alejandro Zelaya angrily said that "no international orga…',
#   'url': 'https://slashdot.org/story/22/02/02/227240/el-salvador-angrily-rejects-imf-call-to-drop-bitcoin-use',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#   'publishedAt': '2022-02-02T23:40:00Z',
#   'content': 'Treasury Minister Alejandro Zelaya angrily said that "no international organization is going to make us do anything, anything at all." Zelaya told a local television station that Bitcoin is an issue … [+607 chars]'},
#  {'source': {'id': None, 'name': 'The Guardian'},
#   'author': 'Rupert Neate Wealth correspondent',
#   'title': 'Bitcoin paradise? Briton creates ‘crypto utopia’ in South Pacific',
#   'description': 'Anthony Welch and partner try to woo cryptocurrency investors to regulation-free island on Vanuatu archipelagoFor the past 12 years Anthony Welch and his partner Theresa have been living a Robinson Crusoe life alone on a South Pacific island mostly untouched …',
# ...
#  {'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Mariella Moon',
#   'title': 'Crypto.com loses $34 million in hack that affected 483 accounts',
#   'description': "In an interview with Bloomberg TV, Crypto.com's Chief Executive Kris Marszalek has admitted that 400 customer accounts were compromised by hackers. He said his team detected unauthorized transactions made from the accounts, but that they'd fixed the issue imm…",
#   'url': 'https://www.engadget.com/cryptocom-loses-34-million-hack-110519248.html',
#   'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-05/58d89ba0-ac94-11eb-97ff-061055b60fc4',
#   'publishedAt': '2022-01-20T11:05:19Z',
#   'content': "In an interview with Bloomberg TV, Crypto.com's Chief Executive Kris Marszalek has admitted that 400 customer accounts were compromised by hackers. He said his team detected unauthorized transactions… [+2811 chars]"},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'msmash',
#   'title': 'Indonesia Regulator Says Financial Firms Banned From Facilitating Crypto Sales',
#   'description': 'Indonesia\'s Financial Services Authority (OJK) on Tuesday warned that financial firms are not allowed to offer and facilitate sales of crypto assets amid a boom in crypto trading in Southeast Asia\'s largest economy. From a report: "OJK has strictly prohibited…',
#   'url': 'https://slashdot.org/story/22/01/25/164212/indonesia-regulator-says-financial-firms-banned-from-facilitating-crypto-sales',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#   'publishedAt': '2022-01-25T16:04:00Z',
#   'content': "wants crypto. It uses a ton of electricity and creates mountains of e-waste (those mining rigs don't last forever and ASICs get replaced with newer/better models constantly). It doesn't even get you … [+309 chars]"},
#  {'source': {'id': None, 'name': 'Entrepreneur'},
#   'author': 'Amanda Breen',
#   'title': 'Dogecoin Jumps 15% After Elon Musk Says Tesla Will Accept the Meme Coin for Merchandise',
#   'description': 'Musk has been a vocal supporter of Dogecoin, frequently firing off tweets that move its price.',
#   'url': 'https://www.entrepreneur.com/article/413246',
#   'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1642174570-GettyImages-1237260173.jpg',
#   'publishedAt': '2022-01-14T15:30:00Z',
#   'content': 'The recent crypto-market surge continued into Friday morning, with Dogecoin initially spiking more than 15% after Tesla announced it would accept the meme coin for some merchandise, CNBC reports.\xa0\r\nE… [+1816 chars]'},
#  {'source': {'id': None, 'name': 'The Guardian'},
#   'author': 'Reuters in Washington',
#   'title': 'US married couple arrested for allegedly conspiring to launder $4.5bn in bitcoin',
#   'description': 'Husband and wife, a rapper on TikTok, are accused in the US’s biggest-ever cryptocurrency theft caseThe US justice department has announced the unraveling of its biggest-ever cryptocurrency theft case, seizing a record-shattering $3.6bn in bitcoin tied to the…',
#   'url': 'https://amp.theguardian.com/technology/2022/feb/08/us-married-couple-arrested-allegedly-conspiring-launder-45bn-bitcoin',
#   'urlToImage': 'https://i.guim.co.uk/img/media/da5a697327125df1ec57a2f8cabd86a9e78ab7dc/0_116_3500_2101/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=8dd7efafe6cda69281a3877417665600',
#   'publishedAt': '2022-02-08T22:48:03Z',
#   'content': 'The US justice department has announced the unraveling of its biggest-ever cryptocurrency theft case, seizing a record-shattering $3.6bn in bitcoin tied to the 2016 hack of digital currency exchange … [+3630 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Robin Kavanagh)',
#   'title': 'Hash rate: A measure of the computing power on a cryptocurrency network that is a key security indicator',
#   'description': "A proof-of-work cryptocurrency's hash rate is an important metric to understand how healthy and secure it is.",
#   'url': 'https://www.businessinsider.com/personal-finance/hash-rate',
#   'urlToImage': 'https://i.insider.com/6202e83d1ed6960018c5bb8d?width=1200&format=jpeg',
#   'publishedAt': '2022-02-08T22:38:46Z',
#   'content': 'Cryptocurrencies like Bitcoin and Ethereum are digital assets that you can buy or sell without having to use an intermediary, such as a bank or broker. Instead, you complete transactions through a bl… [+7252 chars]'},
#  {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#   'author': 'Thomas Macaulay',
#   'title': 'A brief history of El Salvador’s crypto feud with the IMF',
#   'description': 'Investing in crypto is a risky business — particularly when you’re betting with a country’s future. It’s nonetheless a gamble that El Salvador’s president has been eager to make. Nayib Bukele’s splurging on bitcoin has been lauded by crypto advocates, but cri…',
#   'url': 'https://thenextweb.com/news/history-of-el-salvador-imf-crypto-feud-bukele-bitcoin',
#   'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F01%2FUntitled-design-1-5.jpg&signature=76fdc51f69544eea2489aedbec3c239a',
#   'publishedAt': '2022-01-26T22:46:32Z',
#   'content': 'Investing in crypto is a risky business particularly when youre betting with a countrys future. Its nonetheless a gamble that El Salvadors president has been eager to make.\r\nNayib Bukeles splurging o… [+6581 chars]'},
#  {'source': {'id': 'the-globe-and-mail', 'name': 'The Globe And Mail'},
#   'author': 'Tom Wilson and Karen Brettell',
#   'title': 'Bitcoin falls to six-month low as fears of Ukraine conflict shake markets - The Globe and Mail',
#   'description': '<ol><li>Bitcoin falls to six-month low as fears of Ukraine conflict shake markets\xa0\xa0The Globe and Mail\r\n</li><li>Cryptocurrency markets are a sea of red this morning\xa0\xa0Financial Post\r\n</li><li>$130 billion wiped off crypto markets in 24 hours as bitcoin, ether …',
#   'url': 'https://www.theglobeandmail.com/business/international-business/article-bitcoin-falls-to-six-month-low-as-fears-of-ukraine-conflict-shake/',
#   'urlToImage': 'https://www.theglobeandmail.com/resizer/_UFv9QkNJOrvzrIK59uugaqvppQ=/1200x903/filters:quality(80)/cloudfront-us-east-1.images.arcpublishing.com/tgam/RRQIZYKTZZJ7HMT4PXQ7VPGQMI.JPG',
#   'publishedAt': '2022-01-24T13:07:51Z',
#   'content': 'Bitcoin BTF22 tumbled to its lowest level in six months on Monday as fears of a Russian attack on Ukraine saw riskier assets worldwide extend their sell-off.\r\nThe largest cryptocurrency was last down… [+2059 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'U.S. arrests couple for allegedly laundering $4.5 bln in crypto tied to Bitfinex hack - Reuters',
#   'description': 'The FBI arrested a husband and wife on Tuesday morning, alleging they conspired to launder cryptocurrency stolen from the 2016 hack of virtual currency exchange Bitfinex, and said law enforcement has already seized over $3.6 billion in cryptocurrency tied to …',
#   'url': 'https://www.reuters.com/technology/us-arrests-couple-allegedly-laundering-45-bln-crypto-tied-bitfinex-hack-2022-02-08/',
#   'urlToImage': 'https://www.reuters.com/resizer/-zvq-XMuCbYrmKcUeOaOwoCEtxM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/FVEQOZR5FZPPVDW2CTJ5FCJS2I.jpg',
#   'publishedAt': '2022-02-08T16:48:00Z',
#   'content': 'WASHINGTON, Feb 8 (Reuters) - The FBI arrested a husband and wife on Tuesday morning, alleging they conspired to launder cryptocurrency stolen from the 2016 hack of virtual currency exchange Bitfinex… [+2306 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'US dollar net long bets slide to lowest since mid-Sept 2021 -CFTC, Reuters data - Reuters',
#   'description': "Speculators' net long positioning on the U.S. dollar dropped in the latest week to its lowest level since mid-September 2021, according to calculations by Reuters and U.S. Commodity Futures Trading Commission data released on Friday.",
#   'url': 'https://www.reuters.com/markets/currencies/us-dollar-net-long-bets-slide-lowest-since-mid-sept-2021-cftc-reuters-data-2022-01-21/',
#   'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=69',
#   'publishedAt': '2022-01-21T22:37:00Z',
#   'content': "NEW YORK, Jan 21 (Reuters) - Speculators' net long positioning on the U.S. dollar dropped in the latest week to its lowest level since mid-September 2021, according to calculations by Reuters and U.S… [+3071 chars]"},
#  {'source': {'id': None, 'name': 'Entrepreneur'},
#   'author': 'Emily Rella',
#   'title': 'Crypto Exchange Shuts Down Withdrawals After Hackers Reportedly Steal $33 Million in Bitcoin, Ethereum',
#   'description': 'Crypto.com issued a statement after multiple users reported suspicious activity on their accounts.',
#   'url': 'https://www.entrepreneur.com/article/413938',
#   'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1642609239-GettyImages-1191008946.jpg',
#   'publishedAt': '2022-01-19T16:20:48Z',
#   'content': "The crypto market's whiplash volatility\xa0can make investing in certain coins feel like a major gamble, especially to those less familiar\xa0with the ins and outs of digital wallets and blockchain technol… [+1986 chars]"},
#  {'source': {'id': None, 'name': 'Hackaday'},
#   'author': 'Dan Maloney',
#   'title': 'Bitcoin Mining ASICs Repurposed to Keep NTP Server on Track',
#   'description': 'They say time is money, but if that’s true, money must also be time. It’s all figurative, of course, but in the case of this NTP server heater powered by Bitcoin mining dongles, money a…',
#   'url': 'https://hackaday.com/2022/01/12/bitcoin-mining-asics-repurposed-to-keep-ntp-server-on-track/',
#   'urlToImage': 'https://hackaday.com/wp-content/uploads/2022/01/cb2.jpg',
#   'publishedAt': '2022-01-12T21:00:20Z',
#   'content': 'They say time is money, but if that’s true, money must also be time. It’s all figurative, of course, but in the case of this NTP server heater powered by Bitcoin mining dongles, money actually does b… [+1124 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'EditorDavid',
#   'title': 'After Banks Froze Their Accounts, Some Adult Entertainers Turned to Cryptocurrencies',
#   'description': 'CNBC interviewed six adult entertainers about cryptocurrency use, including webcam performer Allie Eve Knox, who became interested in cryptocurrencies after "several vendors, including PayPal, Square Cash, and Venmo, shut down her accounts because of red flag…',
#   'url': 'https://news.slashdot.org/story/22/02/07/020253/after-banks-froze-their-accounts-some-adult-entertainers-turned-to-cryptocurrencies',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#   'publishedAt': '2022-02-07T12:34:00Z',
#   'content': '[T]he biggest attraction was having total and irreversible ownership over the money she had earned. "I could cash it out. I could hold it. I could watch it go up and down," said Knox. "It was mine." … [+2112 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'BeauHD',
#   'title': 'Quantum Computers Are a Million Times Too Small To Hack Bitcoin',
#   'description': 'MattSparkes shares a report from New Scientist: Quantum computers would need to become around one million times larger than they are today in order to break the SHA-256 algorithm that secures bitcoin, which would put the cryptocurrency at risk from hackers. B…',
#   'url': 'https://hardware.slashdot.org/story/22/01/25/2243231/quantum-computers-are-a-million-times-too-small-to-hack-bitcoin',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#   'publishedAt': '2022-01-26T01:25:00Z',
#   'content': 'Quantum computers would need to become around one million times larger than they are today in order to break the SHA-256 algorithm that secures bitcoin, which would put the cryptocurrency at risk fro… [+906 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'hrobertson@businessinsider.com (Harry Robertson)',
#   'title': 'US stock futures dip as investors look toward key inflation data, while bitcoin jumps above $42,000',
#   'description': 'The major US stock markets rallied sharply last week but US inflation data due later this week could trigger more volatility.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-today-us-futures-inflation-federal-reserve-sp500-bitcoin-2022-2',
#   'urlToImage': 'https://i.insider.com/6165d6a3991f6b0018656ab5?width=1200&format=jpeg',
#   'publishedAt': '2022-02-07T10:24:38Z',
#   'content': 'US stock futures slipped Monday after the major indexes posted a solid gain the previous week, with investors looking towards key inflation data due Thursday.\r\nMeanwhile, bitcoin jumped above $42,000… [+2633 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'AFP Videographics',
#   'title': 'Salvadorans react after IMF urges country to stop using bitcoin',
#   'description': '"I disagree with abolishing the bitcoin law," says San Salvador citizen Juan Carlos Perez, after the International Monetary Fund (IMF) called on El Salvador ...',
#   'url': 'https://news.yahoo.com/salvadorans-react-imf-urges-country-051939008.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/GR4rdv38pVxoRNSpTmdTWg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/hd/cp-video-transcode/prod/2022-01/27/61f22c6e9cc3ec27df828918/61f22c6e9cc3ec27df828919_o_U_v2.jpg',
#   'publishedAt': '2022-01-27T05:19:39Z',
#   'content': 'Anna Moneymaker/GettyOn Sept. 4, 2017, according to his confession letter, Joel Greenberg called his friend Rep. Matt Gaetz with some bad news.A teenager both men had paid to have sex with was undera… [+295 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'CBS News Videos',
#   'title': 'MoneyWatch: Super Bowl sports betting, stolen Bitcoin seized, and the Earned Income Tax Credit',
#   'description': 'In this MoneyWatch report, millions of Americans are set to bet on Super Bowl LVI. The Justice Department has seized billions of dollars in stolen Bitcoin...',
#   'url': 'https://news.yahoo.com/moneywatch-super-bowl-sports-betting-140855562.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/5Zr75PtrRlxBslmwl3ATOw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/hd/cp-video-transcode/prod/2022-02/09/6203ce5c8710b13c7681c24f/6203ce5c8710b13c7681c250_o_U_v2.jpg',
#   'publishedAt': '2022-02-09T14:08:55Z',
#   'content': 'ProFootball Talk on NBC Sports\r\nThe Buccaneers have yet to move quarterback Tom Brady from their roster. And for good reason. Before June 1, any effort to shift Brady from the active-roster to a non-… [+142 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Paul Kim)',
#   'title': 'Privacy coins are cryptocurrencies that can be traded anonymously',
#   'description': 'Privacy coins are cryptocurrencies that can be traded anonymously. They are a major issue in the debate between privacy and regulation of cryptocurrency.',
#   'url': 'https://www.businessinsider.com/personal-finance/privacy-coins',
#   'urlToImage': 'https://i.insider.com/6202b552fa4f1f00182681d7?width=1200&format=jpeg',
#   'publishedAt': '2022-02-10T15:35:46Z',
#   'content': "Hundreds of thousands of Bitcoin transactions happen every day. Each transaction and the people involved are recorded on Bitcoin's blockchain, viewable by anyone. Yet, let's imagine that you're buyin… [+6517 chars]"}]

# %%
# Fetch the Ethereum news articles
ethereum_news = newsapi.get_everything(
    q="Ethereum",
    language="en",
    page_size=100, # the number of results to return per page
    sort_by="relevancy"
)

# Print total articles
print(f"Total articles about Ethereum: {ethereum_news['totalResults']}")

# Show the total number of Bitcoin news
ethereum_news["totalResults"]

# Show sample article
ethereum_news["articles"]
# Out:
# Total articles about Ethereum: 3871
# [{'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Corin Faife',
#   'title': 'Crypto.com admits over $30 million stolen by hackers',
#   'description': 'Cryptocurrency exchange Crypto.com has said that $15 million in ethereum and $18 million in bitcoin were stolen by hackers in a security breach',
#   'url': 'https://www.theverge.com/2022/1/20/22892958/crypto-com-exchange-hack-bitcoin-ethereum-security',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/mde_l3lUC4muDPEFG7LYrUz0O3g=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/8921023/acastro_bitcoin_2.jpg',
#   'publishedAt': '2022-01-20T13:23:31Z',
#   'content': 'In a new blog post the company said that 4,836 ETH and 443 bitcoin were taken\r\nIllustration by Alex Castro / The Verge\r\nIn a blog post published in the early hours of Thursday morning, cryptocurrency… [+2004 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Matt Novak',
#   'title': "Hackers Launder $15 Million Stolen From Crypto.com Using Ethereum 'Mixer'",
#   'description': 'Hackers who made off with roughly $15 million in ethereum from Crypto.com are attempting to launder the funds through a so-called ethereum “mixer,” known as Tornado Cash, according to a new report from crypto security company Peck Shield. Mixers run interfere…',
#   'url': 'https://gizmodo.com/hackers-launder-15-million-stolen-from-crypto-com-usin-1848382047',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/095412f6643caa78a11e6be71bceceb4.jpg',
#   'publishedAt': '2022-01-19T12:00:00Z',
#   'content': 'Hackers who made off with roughly $15 million in ethereum from Crypto.com are attempting to launder the funds through a so-called ethereum mixer, known as Tornado Cash, according to a new report from… [+3891 chars]'},
#  {'source': {'id': None, 'name': 'New York Times'},
#   'author': 'Dana Rubinstein, Jonah E. Bromwich and Jeffery C. Mays',
#   'title': 'Eric Adams Is Taking His First Paycheck in Crypto',
#   'description': 'Mr. Adams, who wants New York City to become the global capital for cryptocurrency, will have his paycheck converted into Bitcoin and Ethereum.',
#   'url': 'https://www.nytimes.com/2022/01/20/nyregion/eric-adams-bitcoin-cryptocurrency.html',
#   'urlToImage': 'https://static01.nyt.com/images/2022/01/20/nyregion/20adams-crypto01/20adams-crypto01-facebookJumbo.jpg',
#   'publishedAt': '2022-01-20T19:54:48Z',
#   'content': 'On some level, the new mayor is simply employing an age-old political strategy: making overtures to the business community. Fintech is a growing field in New York City, and blockchain-based companies… [+1562 chars]'},
#  {'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Igor Bonifacic',
#   'title': 'Robinhood opens cryptocurrency wallet to beta testers',
#   'description': 'Back in September\r\n, Robinhood announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availability ahead of a full-scale release. If you joined the wait…',
#   'url': 'https://www.engadget.com/robinhood-cryptocurrency-wallet-beta-225721593.html',
#   'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-09/5035fef0-1bd6-11ec-b7e5-a610838e0b98',
#   'publishedAt': '2022-01-21T22:57:21Z',
#   'content': 'Back in September\r\n, Robinhood announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availa… [+1069 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Omar L. Gallaga',
#   'title': 'Playing With Crypto? You’ll Need a Wallet (or Several)',
#   'description': 'Buying and selling NFTs or transferring digital currency is going to require a little leap of faith. Here’s how to get started.',
#   'url': 'https://www.wired.com/story/how-to-choose-set-up-crypto-wallet/',
#   'urlToImage': 'https://media.wired.com/photos/620415899266d5d11c07b346/191:100/w_1280,c_limit/Gear-Coinbase-App-Screens.jpg',
#   'publishedAt': '2022-02-10T14:00:00Z',
#   'content': "If people who buy cryptocurrencies intended only to hold on to them as speculative investments, there'd be no real need for crypto wallets. Exchanges and online brokerages that convert dollars to, sa… [+3031 chars]"},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Tascha Che',
#   'title': 'Public Blockchains Are the New National Economies of the Metaverse',
#   'description': 'The “fiscal” and “monetary” policy tools of smart contract blockchain platforms\xa0may work even\xa0better than the economic policy tools of governments.',
#   'url': 'https://www.wired.com/story/blockchain-cryptocurrency-economics/',
#   'urlToImage': 'https://media.wired.com/photos/6202ea0049455570f3fe45b9/191:100/w_1280,c_limit/Public-Blockchains-Are-the-New-National-Economies-of-the-Metaverse.jpg',
#   'publishedAt': '2022-02-09T12:00:00Z',
#   'content': 'This enables an L1 platform to bootstrap its national economy over time through a flywheel between financial speculation around its native token and actual building of applications and activities in … [+4057 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Matt Novak',
#   'title': 'Crypto.com Finally Acknowledges $34 Million Stolen by Hackers',
#   'description': 'Trading platform Crypto.com lost about $34 million worth of cryptocurrency in a hack on Monday, according to a new blog post by the company published overnight. The company had previously declined to say much about the hack, which forced users to stop withdra…',
#   'url': 'https://gizmodo.com/crypto-com-finally-acknowledges-34-million-stolen-by-h-1848389819',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/3c7e7ff30b167a88b03f3ef59220cd22.jpg',
#   'publishedAt': '2022-01-20T12:00:00Z',
#   'content': 'Trading platform Crypto.com lost about $34 million worth of cryptocurrency in a hack on Monday, according to a new blog post by the company published overnight. The company had previously declined to… [+2933 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'msmash',
#   'title': 'LooksRare Has Reportedly Generated $8B in Ethereum NFT Wash Trading',
#   'description': "LooksRare seemingly came out of nowhere to become the biggest rival yet to leading NFT marketplace OpenSea earlier this month, but there's a big asterisk on the astronomical trading figures coming out of the platform. From a report: It's marred by rampant was…",
#   'url': 'https://slashdot.org/story/22/01/31/1533225/looksrare-has-reportedly-generated-8b-in-ethereum-nft-wash-trading',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/business_64.png',
#   'publishedAt': '2022-01-31T15:33:00Z',
#   'content': 'The means-and-ends moralists, or non-doers, always end up on their ends\r\nwithout any means.\r\n-- Saul Alinsky'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Carter Kilmann)',
#   'title': 'How to mine Ethereum: A step-by-step guide',
#   'description': "Ethereum mining is a lot more accessible now — here's everything to know about how to mine ether.",
#   'url': 'https://www.businessinsider.com/personal-finance/how-to-mine-ethereum',
#   'urlToImage': 'https://i.insider.com/61d7130f95f1b9001837813d?width=1200&format=jpeg',
#   'publishedAt': '2022-01-18T21:40:58Z',
#   'content': "Ethereum is a digital platform that runs on blockchain technology. It's most commonly known for its smart contract functionality and native cryptocurrency, ether. The broader purpose of the Ethereum … [+10591 chars]"},
#  {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#   'author': 'Thomas Macaulay',
#   'title': 'Ethereum inventor wants to replace pregnant women with synthetic wombs',
#   'description': 'Crypto bros never tire of sharing their utopian visions, but their big brain ideas aren’t always embraced by the proles. Vitalik Buterin, the co-founder and inventor of Ethereum, has become the latest victim of this insolence. The 27-year-old had pitched a bo…',
#   'url': 'https://thenextweb.com/news/ethereum-founder-vitalik-buterin-wants-synthetic-wombs',
#   'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F01%2FUntitled-design-2-4.jpg&signature=8b0bf04a88388b1e5a9859dfd538d68a',
#   'publishedAt': '2022-01-20T20:11:43Z',
#   'content': 'Crypto bros never tire of sharing their utopian visions, but their big brain ideas arent always embraced by the proles.\r\nVitalik Buterin, the co-founder and inventor of Ethereum, has become the lates… [+1727 chars]'},
#  {'source': {'id': None, 'name': 'Entrepreneur'},
#   'author': 'Emily Rella',
#   'title': 'Crypto Exchange Shuts Down Withdrawals After Hackers Reportedly Steal $33 Million in Bitcoin, Ethereum',
#   'description': 'Crypto.com issued a statement after multiple users reported suspicious activity on their accounts.',
#   'url': 'https://www.entrepreneur.com/article/413938',
#   'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1642609239-GettyImages-1191008946.jpg',
#   'publishedAt': '2022-01-19T16:20:48Z',
#   'content': "The crypto market's whiplash volatility\xa0can make investing in certain coins feel like a major gamble, especially to those less familiar\xa0with the ins and outs of digital wallets and blockchain technol… [+1986 chars]"},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Polygon raises $450 mln from Sequoia Capital India, SoftBank Vision Fund 2, others - Reuters',
#   'description': 'Polygon, a decentralized scaling platform for the ethereum blockchain, announced on Monday it has raised $450 million in its latest funding round led by Sequoia Capital India and including investments from SoftBank\'s <a href="https://www.reuters.com/companies…',
#   'url': 'https://www.reuters.com/markets/funds/polygon-raises-450-mln-sequoia-capital-india-softbank-vision-fund-2-others-2022-02-07/',
#   'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=70',
#   'publishedAt': '2022-02-07T16:38:00Z',
#   'content': 'Feb 7 (Reuters) - Polygon, a decentralized scaling platform for the ethereum blockchain, announced on Monday it has raised $450 million in its latest funding round led by Sequoia Capital India and in… [+1641 chars]'},
#  {'source': {'id': None, 'name': 'The Economist'},
#   'author': 'The Economist',
#   'title': 'The race to dominate the DeFi ecosystem is on',
#   'description': 'Why Ethereum is losing market share',
#   'url': 'https://www.economist.com/finance-and-economics/2022/01/22/the-race-to-dominate-the-defi-ecosystem-is-on',
#   'urlToImage': 'https://www.economist.com/img/b/1280/720/90/sites/default/files/images/print-edition/20220122_FND001_0.jpg',
#   'publishedAt': '2022-01-20T11:54:38Z',
#   'content': 'TO BELIEVERS, OPEN, public blockchains provide a second chance at building a digital economy. The fact that the applications built on top of such blockchains all work with each other, and that the in… [+6735 chars]'},
#  {'source': {'id': None, 'name': 'The Economist'},
#   'author': 'The Economist',
#   'title': 'The race to power the DeFi ecosystem is on',
#   'description': 'Why Ethereum is losing market share',
#   'url': 'https://www.economist.com/finance-and-economics/the-race-to-power-the-defi-ecosystem-is-on/21807229',
#   'urlToImage': 'https://www.economist.com/img/b/1280/720/90/sites/default/files/images/2022/01/articles/main/20220122_fnd001.jpg',
#   'publishedAt': '2022-01-16T00:00:00Z',
#   'content': 'TO BELIEVERS, OPEN, public blockchains provide a second chance at building a digital economy. The fact that the applications built on top of such blockchains all work with each other, and that the in… [+6577 chars]'},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Steven Musil',
#   'title': "Blockchain platform Wormhole says it's retrieved the $324M stolen by hackers - CNET",
#   'description': 'Developers behind the popular blockchain bridge says services back up too.',
#   'url': 'https://www.cnet.com/personal-finance/crypto/blockchain-platform-wormhole-says-its-retrieved-the-324m-stolen-by-hackers/',
#   'urlToImage': 'https://www.cnet.com/a/img/EmZwZ3SriHUmfsfozP7kAv4d4PY=/1200x630/2022/02/03/c1ba1964-e7c2-44cd-a912-41fdc18e3866/gettyimages-1232534041.jpg',
#   'publishedAt': '2022-02-03T14:32:00Z',
#   'content': 'Online thieves made off with "wrapped ethereum" worth nearly $324 million.\r\nGetty Images\r\nHackers stole more than $324 million in cryptocurrency from Wormhole, the developers behind the popular block… [+1664 chars]'},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Steven Musil',
#   'title': 'Hacker steals over $320M from blockchain platform Wormhole - CNET',
#   'description': 'Developers behind the popular blockchain bridge offer the hacker a $10 million "bug bounty" for info about the exploit and return of the stolen cryptocurrency.',
#   'url': 'https://www.cnet.com/personal-finance/crypto/hacker-steals-over-320m-from-blockchain-platform-wormhole/',
#   'urlToImage': 'https://www.cnet.com/a/img/EmZwZ3SriHUmfsfozP7kAv4d4PY=/1200x630/2022/02/03/c1ba1964-e7c2-44cd-a912-41fdc18e3866/gettyimages-1232534041.jpg',
#   'publishedAt': '2022-02-03T03:15:00Z',
#   'content': 'Online thieves made off with 120,000 wEth, or wrapped Ethereum, worth nearly $324 million.\r\nGetty Images\r\nHackers have stolen more than $324 million in cryptocurrency from Wormhole, the developers be… [+1553 chars]'},
#  {'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Mariella Moon',
#   'title': 'Crypto.com loses $34 million in hack that affected 483 accounts',
#   'description': "In an interview with Bloomberg TV, Crypto.com's Chief Executive Kris Marszalek has admitted that 400 customer accounts were compromised by hackers. He said his team detected unauthorized transactions made from the accounts, but that they'd fixed the issue imm…",
#   'url': 'https://www.engadget.com/cryptocom-loses-34-million-hack-110519248.html',
#   'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-05/58d89ba0-ac94-11eb-97ff-061055b60fc4',
#   'publishedAt': '2022-01-20T11:05:19Z',
#   'content': "In an interview with Bloomberg TV, Crypto.com's Chief Executive Kris Marszalek has admitted that 400 customer accounts were compromised by hackers. He said his team detected unauthorized transactions… [+2811 chars]"},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Gian M. Volpicelli',
#   'title': 'Gibraltar Could Launch the World’s First Crypto Stock Exchange',
#   'description': '“The Rock” hopes a new stock exchange will attract crypto millionaires who want to avoid hefty taxes.',
#   'url': 'https://www.wired.com/story/gibraltar-crypto-exchange/',
#   'urlToImage': 'https://media.wired.com/photos/61f0b4bf03f9ae99229f47d4/191:100/w_1280,c_limit/Business_Gibraltar-1208348908.jpg',
#   'publishedAt': '2022-01-26T12:00:00Z',
#   'content': 'British entrepreneur and financier Richard ODell Poulden hopes that his new venture will relieve the plight of an underserved cohort: Bitcoin billionaires who want to buy a house.\r\nIn October, Poulde… [+3364 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Bitcoin surges 8.82% to $40611 - Reuters',
#   'description': 'Bitcoin surged 8.82% to $40,611.4 at 2202 GMT on Friday, adding $3,291.29 to its previous close.',
#   'url': 'https://www.reuters.com/technology/bitcoin-surges-882-40611-2022-02-04/',
#   'urlToImage': 'https://www.reuters.com/resizer/iF8DKAnETeNHBq1q1qRRQFe4oZo=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/5KHWYF53XBNEFLDIU4B47BZYQE.jpg',
#   'publishedAt': '2022-02-04T22:27:00Z',
#   'content': "Feb 4 (Reuters) - Bitcoin surged 8.82% to $40,611.4 at 2202 GMT on Friday, adding $3,291.29 to its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is up 23.2% from the ye… [+321 chars]"},
#  {'source': {'id': 'time', 'name': 'Time'},
#   'author': 'Andrew R. Chow',
#   'title': 'How Blockchain Could Solve the Problem of Digital Identity',
#   'description': 'When Vitalik Buterin, the founder of Ethereum, has been asked lately about his favorite projects being built on the blockchain, he often names Proof of Humanity.',
#   'url': 'https://time.com/6142810/proof-of-humanity/',
#   'urlToImage': 'https://api.time.com/wp-content/uploads/2022/01/IMG_3792.jpeg?quality=85&crop=0px%2C273px%2C1125px%2C588px&resize=1200%2C628&strip',
#   'publishedAt': '2022-01-27T09:39:28Z',
#   'content': 'A version of this article was published in TIME’s newsletter Into the Metaverse. Subscribe for a weekly guide to the future of the Internet.You can find past issues of the newsletter here.\r\nWhen Vita… [+9697 chars]'},
#  {'source': {'id': 'time', 'name': 'Time'},
#   'author': 'Yueqi Yang and Shelly Banjo / Bloomberg',
#   'title': 'New York City Mayor Eric Adams Will Convert His First Paycheck Into Cryptocurrency',
#   'description': 'New York City Mayor Eric Adams confirmed his first paycheck—which arrives on Friday—will be converted into Bitcoin and Ethereum.',
#   'url': 'https://time.com/6140923/new-york-city-mayor-adams-cryptocurrency/',
#   'urlToImage': 'https://api.time.com/wp-content/uploads/2022/01/383163992.jpg?quality=85&w=1200&h=628&crop=1',
#   'publishedAt': '2022-01-21T02:40:38Z',
#   'content': 'New York City Mayor Eric Adams confirmed his first paycheck—which arrives on Friday—will be converted into Bitcoin and Ethereum.\r\nCoinbase Global Inc., the largest U.S. cryptocurrency exchange, will … [+1880 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'GameStop taps Immutable X for NFT marketplace - Reuters',
#   'description': 'GameStop Corp <a href="https://www.reuters.com/companies/GME.N" target="_blank">(GME.N)</a> is partnering with blockchain startup Immutable X to launch its non-fungible token (NFT) marketplace later this year, as it looks to take advantage of the booming mark…',
#   'url': 'https://www.reuters.com/technology/gamestop-taps-immutable-x-nft-marketplace-2022-02-03/',
#   'urlToImage': 'https://www.reuters.com/resizer/wP0VN7L3f1ZWje-bms43pqrvmIc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/NTLEPRTY65J2RFWMY7AMSNB534.jpg',
#   'publishedAt': '2022-02-03T13:10:00Z',
#   'content': 'Feb 3 (Reuters) - GameStop Corp (GME.N) is partnering with blockchain startup Immutable X to launch its non-fungible token (NFT) marketplace later this year, as it looks to take advantage of the boom… [+1566 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'OnlyFans jumps into NFT profile pictures - Reuters',
#   'description': 'OnlyFans, an online subscription platform known for adult content, has launched a feature for users to display verified NFTs as profile pictures, it said on Thursday.',
#   'url': 'https://www.reuters.com/technology/onlyfans-jumps-into-nft-profile-pictures-2022-02-10/',
#   'urlToImage': 'https://www.reuters.com/resizer/Rac64dW-6Hs2FT3MOTHKVoXaK8Q=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/PSNU7CKVIZPZ7FUX2GKGOXCJ3I.jpg',
#   'publishedAt': '2022-02-10T18:48:00Z',
#   'content': 'Feb 10 (Reuters) - OnlyFans, an online subscription platform known for adult content, has launched a feature for users to display verified NFTs as profile pictures, it said on Thursday.\r\nThe UK-based… [+1752 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Bitcoin falls 9.3% to $36955 - Reuters',
#   'description': 'Bitcoin dropped 9.28% to $36,955.03 at 22:02 GMT on Friday, losing $3,781.02 from its previous close.',
#   'url': 'https://www.reuters.com/technology/bitcoin-falls-93-36955-2022-01-21/',
#   'urlToImage': 'https://www.reuters.com/resizer/dAgPtOWZKLDrKS2Jwdrqn294sU0=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/HJLMCJEIPNKXBEOQ6T3SCMFCEM.jpg',
#   'publishedAt': '2022-01-21T23:30:00Z',
#   'content': 'A representation of virtual currency Bitcoin is seen in front of a stock graph in this illustration taken January 8, 2021. REUTERS/Dado Ruvic/File PhotoJan 21 (Reuters) - Bitcoin dropped 9.28% to $36… [+508 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Russian lender TCS buys Swiss crypto exchange Aximetria - Reuters',
#   'description': 'Russian lender TCS Group Holding <a href="https://www.reuters.com/companies/TCSq.L" target="_blank">(TCSq.L)</a> on Wednesday said it planned to develop Swiss crypto exchange Aximetria as part of its international expansion and would later disclose details of…',
#   'url': 'https://www.reuters.com/technology/russian-lender-tcs-buys-swiss-crypto-exchange-aximetria-2022-01-12/',
#   'urlToImage': 'https://www.reuters.com/resizer/IyINB5E-MvaiHmoC4cJFU9mgtIY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/55XZTMF22JPCFPSOTVFD67MOJQ.jpg',
#   'publishedAt': '2022-01-12T11:16:00Z',
#   'content': 'Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/Illustration\r\nMOSCOW, Jan … [+533 chars]'},
#  {'source': {'id': None, 'name': 'Blogspot.com'},
#   'author': 'noreply@blogger.com (Unknown)',
#   'title': 'Most Frequently Asked Questions About NFTs(Non-Fungible Tokens)',
#   'description': 'Non-fungible tokens (NFTs) are the most popular digital assets today, capturing the attention of cryptocurrency investors, whales and people from around the world. People find it amazing that some users spend thousands or millions of dollars on a single NFT-b…',
#   'url': 'https://techncruncher.blogspot.com/2022/02/most-frequently-asked-questions-about.html',
#   'urlToImage': 'https://blogger.googleusercontent.com/img/a/AVvXsEhQ__o2Bk7fjBlzcWaYTiBTTZ95DOPWpTIDWtMzAr9krA18i_9rwyAg6cHLKxIeFHR5Y194Rk7Xl8hXQYUME-yYDOGmLnm6LMvHEIRKdgBqcKD7348U3UE5l2a2T0s1xRm0id0LQOUoKvgeXl-QGtgUTwIyYeCR22MVLenD6zzunb9BG_Vhca6cJm3bAg=w640-h360',
#   'publishedAt': '2022-02-06T10:04:00Z',
#   'content': 'Non-fungible tokens (NFTs) are the most popular digital assets today, capturing the attention of cryptocurrency investors, whales and people from around the world. People find it amazing that some us… [+6463 chars]'},
#  {'source': {'id': None, 'name': 'Entrepreneur'},
#   'author': 'Chloe Arrojado',
#   'title': "Fears of the Fed's Policy Changes Send Huge Losses in the Cryptocurrency Market",
#   'description': 'Bitcoin is now valued at around half of its November market highs.',
#   'url': 'https://www.entrepreneur.com/article/414714',
#   'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1643039603-shutterstock-1975856621.jpg',
#   'publishedAt': '2022-01-24T15:53:52Z',
#   'content': 'The volatile cryptocurrency market is taking a hit as the Fed is expected to hike interest rates\xa0in an effort to combat inflation.\r\n"Central banks and governments have played a role in jacking up the… [+1302 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'NYC Mayor Eric Adams to receive first paycheck in cryptocurrency via Coinbase - Reuters',
#   'description': 'New York City Mayor Eric Adams on Thursday said his first paycheck, to arrive Friday, will be automatically converted into cryptocurrency via Coinbase Global Inc <a href="https://www.reuters.com/companies/COIN.O" target="_blank">(COIN.O)</a>.',
#   'url': 'https://www.reuters.com/world/us/nyc-mayor-eric-adams-receive-first-paycheck-cryptocurrency-via-coinbase-2022-01-20/',
#   'urlToImage': 'https://www.reuters.com/resizer/iHi1Lcrgc_ZmzW_1UoM_79ZTrYE=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/YXQNFRDSFNKULCFJKQZAWAHRDQ.jpg',
#   'publishedAt': '2022-01-20T15:26:00Z',
#   'content': 'New York City Mayor Eric Adams speaks at an event during the coronavirus disease (COVID-19) pandemic in the Bronx borough of New York City, New York, U.S., January 3, 2022. REUTERS/Carlo Allegri/File… [+625 chars]'},
#  {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#   'author': 'The Conversation',
#   'title': 'WWF debacle makes it clear that ‘eco-friendly’ NFTs don’t really exist',
#   'description': 'Most online images are just a right-click away from being in someone’s personal collection. They’re free, pretty much. So it’s tough for charities to fundraise with them. That is, until 2017 when non-fungible tokens, or NFTs, came along. Unlike regular pieces…',
#   'url': 'https://thenextweb.com/news/nfts-are-bad-idea-for-environmental-charities-fundraising-efforts',
#   'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F02%2FWWF-NFTs.jpg&signature=2e8b20b201af3a5d321666d8a8db8a8c',
#   'publishedAt': '2022-02-10T13:07:10Z',
#   'content': 'Most online images are just a right-click away from being in someones personal collection. Theyre free, pretty much. So its tough for charities to fundraise with them. That is, until 2017 when non-fu… [+5776 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'ilee@insider.com (Isabelle Lee)',
#   'title': 'GameStop is launching its NFT marketplace on carbon-neutral blockchain platform Immutable X as the retailer and meme-stock icon dives into digital collectibles',
#   'description': 'GameStop is also creating a $100 million fund alongside Immutable X to support game developers and studios that will partner with them.',
#   'url': 'https://markets.businessinsider.com/news/currencies/gamestop-nft-marketplace-immutable-x-carbon-neutral-gme-ethereum-crypto-2022-2',
#   'urlToImage': 'https://i.insider.com/61faebf64e4b5500188badfa?width=1200&format=jpeg',
#   'publishedAt': '2022-02-03T12:00:00Z',
#   'content': 'GameStop has selected a key partner to help launch a non-fungible token marketplace for gamers to ride the boom in digital collectibles.\xa0\r\nThe video game retailer will use the \r\nliquidity platform of… [+1994 chars]'},
#  {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#   'author': 'Ivan Mehta',
#   'title': 'Everything you need to know about those .eth addresses on Twitter',
#   'description': 'Welcome to\xa0TNW Basics, a collection of tips, guides, and advice on how to easily get the most out of your gadgets, apps, and other stuff. If you’ve been on Twitter recently, you’ll have seen people donning a username with an .eth suffix. You can see an exampl…',
#   'url': 'https://thenextweb.com/news/eth-addresses-twitter-ens-crypto-nft',
#   'urlToImage': 'https://img-cdn.tnwcdn.com/image/tnw?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F02%2FTrump-eth.jpg&signature=40850a9d10323d9436c9ea738cd171aa',
#   'publishedAt': '2022-02-08T13:10:09Z',
#   'content': 'Welcome to\xa0TNW Basics, a collection of tips, guides, and advice on how to easily get the most out of your gadgets, apps, and other stuff.\r\nIf youve been on Twitter recently, youll have seen people do… [+3873 chars]'},
#  {'source': {'id': None, 'name': 'Boing Boing'},
#   'author': 'Jason Weisberger',
#   'title': 'Second largest NFT marketplace apparently 87% wash trading',
#   'description': 'Wash trading, wherein a seller buys and sells the same asset to generate a false impression of marketplace activity and demand, appears to be most of the action on NFT marketplace Looksrare.\n\n\n\nDecrypt:\n\n\n\nNFT analytics firm\xa0CryptoSlam\xa0reported today that it …',
#   'url': 'https://boingboing.net/2022/01/31/second-largest-nft-marketplace-apparently-87-wash-trading.html',
#   'urlToImage': 'https://i1.wp.com/boingboing.net/wp-content/uploads/2022/01/shutterstock_755680090.jpg?fit=1000%2C667&ssl=1',
#   'publishedAt': '2022-01-31T18:36:56Z',
#   'content': 'Wash trading, wherein a seller buys and sells the same asset to generate a false impression of marketplace activity and demand, appears to be most of the action on NFT marketplace Looksrare.NFT analy… [+922 chars]'},
#  {'source': {'id': None, 'name': 'Ethereum.org'},
#   'author': 'Ethereum Foundation',
#   'title': 'The great renaming: what happened to Eth2?',
#   'description': 'Ethereum is a protocol undergoing significant changes. Client teams are upgrading the protocol to scale to meet global demand while improving security and decentralization. Beyond protocol development, a critical shift in Ethereum has been the movement away f…',
#   'url': 'https://blog.ethereum.org/2022/01/24/the-great-eth2-renaming/',
#   'urlToImage': 'https://blog.ethereum.org/img/ethereum-blog-og-image.png',
#   'publishedAt': '2022-01-25T00:54:39Z',
#   'content': 'Ethereum is a protocol undergoing significant changes. Client teams are upgrading the protocol to scale to meet global demand while improving security and decentralization. Beyond protocol developmen… [+5874 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'ilee@insider.com (Isabelle Lee)',
#   'title': 'Shiba inu rallies 50% to a new 2022 high as meme coins soar',
#   'description': 'Other meme coins from dogecoin to floki inu also gained on Monday after suffering from a recent slump.',
#   'url': 'https://markets.businessinsider.com/news/currencies/shiba-inu-price-meme-coins-crypto-dogecoin-bitcoin-ether-fed-2022-2',
#   'urlToImage': 'https://i.insider.com/6178ff635d1dca0019a127a4?width=1200&format=jpeg',
#   'publishedAt': '2022-02-07T19:04:03Z',
#   'content': 'The dogecoin-inspired cryptocurrency shiba inu jumped to its highest for the year on Monday amid a broader rally in meme coins.\r\nThe token gained 51.12% in 24 hours to stand at $0.00003492 by 1:11 p.… [+2389 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Robinhood to start rolling out crypto wallets - Reuters',
#   'description': 'Robinhood Markets Inc <a href="https://www.reuters.com/companies/HOOD.O" target="_blank">(HOOD.O)</a> is rolling out crypto wallets to a 1,000 users, allowing them to send and receive cryptocurrencies through their brokerage accounts, the company said in a bl…',
#   'url': 'https://www.reuters.com/technology/robinhood-start-rolling-out-crypto-wallets-2022-01-20/',
#   'urlToImage': 'https://www.reuters.com/resizer/5MEqCXoeczeUuqKC0hbnBVZfDOM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/RQ4FKZJM4JNE3IE45KCFIE2U4U.jpg',
#   'publishedAt': '2022-01-20T23:41:00Z',
#   'content': 'Jan 20 (Reuters) - Robinhood Markets Inc (HOOD.O) is rolling out crypto wallets to a 1,000 users, allowing them to send and receive cryptocurrencies through their brokerage accounts, the company said… [+1253 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Tiger Global, Sapphire led funding round values block chain firm Blockdaemon at $3.25 bln - Reuters',
#   'description': 'Tiger Global Management and Sapphire led a $207 million financing round in Blockdaemon, valuing the block chain firm at $3.25 billion, the company said on Wednesday.',
#   'url': 'https://www.reuters.com/markets/us/tiger-global-sapphire-led-funding-round-values-block-chain-firm-blockdaemon-325-2022-01-26/',
#   'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=69',
#   'publishedAt': '2022-01-26T22:08:00Z',
#   'content': 'Jan 26 (Reuters) - Tiger Global Management and Sapphire led a $207 million financing round in Blockdaemon, valuing the block chain firm at $3.25 billion, the company said on Wednesday.\r\nSeveral large… [+1279 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Intel launches blockchain chip to tap crypto boom - Reuters',
#   'description': 'Intel Corp on Friday launched a new chip for blockchain applications such as Bitcoin mining and minting NFTs to cash in on the rising usage of cryptocurrencies.',
#   'url': 'https://www.reuters.com/technology/intel-launches-blockchain-chip-tap-crypto-boom-2022-02-11/',
#   'urlToImage': 'https://www.reuters.com/resizer/xofDHdDSZIcvlRX0ucwH1xj5Hv4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/CQCFIUFLXNM7PH4PYYZKNCYNAE.jpg',
#   'publishedAt': '2022-02-11T18:14:00Z',
#   'content': 'Feb 11 (Reuters) - Intel Corp on Friday launched a new chip for blockchain applications such as Bitcoin mining and minting NFTs to cash in on the rising usage of cryptocurrencies.\r\nThe chip will ship… [+1192 chars]'},
#  {'source': {'id': 'time', 'name': 'Time'},
#   'author': 'Megan McCluskey',
#   'title': 'How Crypto Investors Are Handling Plunging Prices',
#   'description': 'Amid a sharp plunge for Bitcoin and other top tokens like Ethereum and Solana, some cryptocurrency investors say they’re taking a long-term view of the market to weather the storm. Following a rough week, Bitcoin’s price climbed back up to hover in the $38,00…',
#   'url': 'https://time.com/6141028/crypto-crash-investors/',
#   'urlToImage': 'https://api.time.com/wp-content/uploads/2022/01/Crypto-Drop.jpg?quality=85&w=496&h=347&crop=1',
#   'publishedAt': '2022-02-01T17:03:10Z',
#   'content': 'Amid a sharp plunge for Bitcoin and other top tokens like Ethereum and Solana, some cryptocurrency investors say they’re taking a long-term view of the market to weather the storm.\r\nFollowing a rough… [+6300 chars]'},
#  {'source': {'id': None, 'name': 'The Guardian'},
#   'author': 'Alex Hern',
#   'title': 'TechScape: everything you need to know about DAOs',
#   'description': 'In this week’s newsletter: meet the vehicle for newly-minted online millionaires to throw their influence into the real world – and the frontier for the next wave of crypto chaos<ul><li>Don’t get TechScape delivered to your inbox? Sign up for the full article…',
#   'url': 'https://amp.theguardian.com/technology/2022/jan/26/techscape-daos-nfts',
#   'urlToImage': 'https://i.guim.co.uk/img/media/9838ce57fe31f8317de90f35414fb366a307a6be/0_96_3000_1800/master/3000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=bc0caf659c39527c57e6412574374a85',
#   'publishedAt': '2022-01-26T11:45:00Z',
#   'content': 'Its a new year, so its time for a new cryptocurrency buzzword to escape the sector and become the latest fad that baffled news anchors try desperately to explain to their increasingly confused audien… [+8017 chars]'},
#  {'source': {'id': None, 'name': 'Ctvnews.ca'},
#   'author': 'Diksha Madhok',
#   'title': 'Bitcoin value tumbles almost 50 per cent since record November - CTV News',
#   'description': '<ol><li>Bitcoin value tumbles almost 50 per cent since record November\xa0\xa0CTV News\r\n</li><li>Bitcoin crashes to five-month low as Russia proposes crypto ban\xa0\xa0Yahoo Canada Finance\r\n</li><li>Like ‘The 1929 Crash’—New Crypto Winter Warning As Sell-Off Wipes $1.5 T…',
#   'url': 'https://www.ctvnews.ca/sci-tech/bitcoin-value-tumbles-almost-50-per-cent-since-record-november-1.5750783',
#   'urlToImage': 'https://www.ctvnews.ca/polopoly_fs/1.5750786.1642871612!/httpImage/image.jpg_gen/derivatives/landscape_620/image.jpg',
#   'publishedAt': '2022-01-22T17:14:25Z',
#   'content': "Bitcoin has lost almost half its value since its November high, with cryptocurrency prices continuing to plunge as major economies look to curb their growing popularity.\r\nAnd it's not just Bitcoin, a… [+1912 chars]"},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Oscar Holland, CNN',
#   'title': "My big fat digital wedding: Indian couple plan country's 'first metaverse marriage'",
#   'description': 'As Covid-19 forces families across India to downsize or cancel their traditionally large-scale weddings, one couple has found a venue unaffected by restrictions: the metaverse.',
#   'url': 'https://www.cnn.com/style/article/india-wedding-metaverse/index.html',
#   'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/220123193550-01-india-metaverse-wedding-super-tease.jpg',
#   'publishedAt': '2022-01-24T05:08:51Z',
#   'content': 'designPublished 24th January 2022\r\nAs Covid-19 forces families across India to downsize or cancel their traditionally large-scale weddings, one couple has found a venue unaffected by restrictions: th… [+2651 chars]'},
#  {'source': {'id': None, 'name': 'MakeUseOf'},
#   'author': 'Katie Rees',
#   'title': 'The 8 Best Ethereum Wallets for Your Funds',
#   'description': 'Looking for a crypto wallet to securely store all your Ethereum? Here are some of the best Ethereum wallets you can use to keep your funds safe.',
#   'url': 'https://www.makeuseof.com/best-ethereum-wallets/',
#   'urlToImage': 'https://static1.makeuseofimages.com/wordpress/wp-content/uploads/2022/01/ethereum-stack-1-(1).jpg',
#   'publishedAt': '2022-01-24T17:00:12Z',
#   'content': 'In 2022, Ethereum stands as the second-most valuable cryptocurrency behind Bitcoin. Thousands of people buy and sell Ethereum every day, but owning Ethereum requires storing your private keys securel… [+8900 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Robin Kavanagh)',
#   'title': 'Hash rate: A measure of the computing power on a cryptocurrency network that is a key security indicator',
#   'description': "A proof-of-work cryptocurrency's hash rate is an important metric to understand how healthy and secure it is.",
#   'url': 'https://www.businessinsider.com/personal-finance/hash-rate',
#   'urlToImage': 'https://i.insider.com/6202e83d1ed6960018c5bb8d?width=1200&format=jpeg',
#   'publishedAt': '2022-02-08T22:38:46Z',
#   'content': 'Cryptocurrencies like Bitcoin and Ethereum are digital assets that you can buy or sell without having to use an intermediary, such as a bank or broker. Instead, you complete transactions through a bl… [+7252 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'msmash',
#   'title': 'An OpenSea Bug Let Attackers Snatch NFTs from Owners at Six-figure Discounts',
#   'description': 'A bug in OpenSea, the popular NFT marketplace, has let hackers buy rare NFTs for well below market value, in some cases leading to hundreds of thousands of dollars in losses for the original owners -- and hundreds of thousands of dollars in profits for the ap…',
#   'url': 'https://it.slashdot.org/story/22/01/24/1733244/an-opensea-bug-let-attackers-snatch-nfts-from-owners-at-six-figure-discounts',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/security_64.png',
#   'publishedAt': '2022-01-24T17:33:00Z',
#   'content': 'The bug appears to have been present for weeks and seems to be referenced in at least one tweet from January 1st, 2022. But exploitation of the bug has picked up significantly in the past day: blockc… [+1179 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Adam Morgan McCarthy)',
#   'title': "The Australian Open's metaverse turns Rafael Nadal's Grand Slam-winning shot into a potential 4,000% NFT gain",
#   'description': "The value of bids for the NFT where champion Rafael Nadal's winning shot landed has surged more than 4,000% from the floor price.",
#   'url': 'https://markets.businessinsider.com/news/currencies/rafael-nadal-australia-open-crypto-nft-metaverse-tennis-gain-ash-barty-2022-1',
#   'urlToImage': 'https://i.insider.com/61f815a5415c3f0018d3b72b?width=1200&format=jpeg',
#   'publishedAt': '2022-01-31T18:37:52Z',
#   'content': "Australian Open champions Ash Barty and Rafael Nadal weren't the only winners from the tennis tournament, which played out in a dedicated metaverse at the same time it did in Melbourne.\r\nSome NFT buy… [+3231 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'prosen@insider.com (Phil Rosen)',
#   'title': 'China to launch state-run NFT blockchain that is entirely separate from cryptocurrencies',
#   'description': "China's state-backed Blockchain Services Network will launch a new infrastructure to support NFTs, after Beijing banned crypto transactions last year.",
#   'url': 'https://markets.businessinsider.com/news/currencies/china-nft-blockchain-ban-cryptocurrencies-state-run-digital-assets-2022-1',
#   'urlToImage': 'https://images2.markets.businessinsider.com/61e08505c5e27c00185b7931?format=jpeg',
#   'publishedAt': '2022-01-13T20:17:20Z',
#   'content': "A truck returns over the Friendship Bridge from the North Korean town of Sinuiju to the Chinese border city of Dandong, in China's northeast Liaoning province on January 9, 2018.CHANDAN KHANNA/AFP vi… [+1745 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'ilee@insider.com (Isabelle Lee)',
#   'title': 'Gucci just bought a plot of virtual land in The Sandbox to create themed experiences in the metaverse',
#   'description': 'The luxury brand said it is expanding Gucci Vault, its Gen Z focused online concept store, to create an interactive fashion experience.',
#   'url': 'https://markets.businessinsider.com/news/currencies/gucci-sandbox-metaverse-land-ethereum-roblox-nft-crypto-vault-2022-2',
#   'urlToImage': 'https://i.insider.com/62051233e2fe3c0019e9f0cf?width=1200&format=jpeg',
#   'publishedAt': '2022-02-10T14:45:06Z',
#   'content': 'Iconic fashion house Gucci has entered the metaverse by buying a plot of digital land in The Sandbox, a virtual world on the ethereum blockchain, as the Italian brand looks to tap the Gen Z market.\r\n… [+1579 chars]'},
#  {'source': {'id': None, 'name': 'Theregister.com'},
#   'author': 'Thomas Claburn',
#   'title': "Crypto.com acknowledges 'unauthorized activity' on servers, maintains no funds have been lost",
#   'description': 'Security biz PeckShield claims $15m in Ethereum taken\nCrypto.com, a Singapore-based cryptocurrency exchange, has denied reports that the firm lost nearly $15m in Ethereum in a possible network intrusion over the weekend.…',
#   'url': 'https://www.theregister.com/2022/01/18/crypto_com_security_incident/',
#   'urlToImage': 'https://regmedia.co.uk/2021/02/11/shutterstock_data_thief.jpg',
#   'publishedAt': '2022-01-18T21:12:04Z',
#   'content': 'Crypto.com, a Singapore-based cryptocurrency exchange, has denied reports that the firm lost nearly $15m in Ethereum in a possible network intrusion over the weekend.\r\nAccording to blockchain biz Pec… [+2208 chars]'},
#  {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#   'author': 'The Conversation',
#   'title': 'Crypto theft is reaching new heights — here’s how to protect your stash',
#   'description': 'News emerged overnight of the potential theft of more than US$326 million (A$457.7 million) of Ethereum tokens from a blockchain bridge (which connects two blockchains so cryptocurrency can be exchanged between them). It’s no surprise. Crypto crime has been o…',
#   'url': 'https://thenextweb.com/news/crypto-theft-reaching-new-heights-how-to-protect-your-stash',
#   'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F02%2Fstealing-crypto.jpeg&signature=b64f7e2d6aec1309e8802627c63a7423',
#   'publishedAt': '2022-02-09T08:32:50Z',
#   'content': 'News emerged overnight of the potential theft of more than US$326 million (A$457.7 million) of Ethereum tokens from a blockchain bridge (which connects two blockchains so cryptocurrency can be exchan… [+6968 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'BeauHD',
#   'title': 'DeFi Platform Qubit Finance Begs Hacker To Return $80 Million In Stolen Funds',
#   'description': 'Qubit Finance took to Twitter last night to beg hackers to return more than $80 million in stolen cryptocurrency this week. ZDNet reports: On Thursday, the DeFi platform said their protocol was exploited by a hacker who eventually stole 206,809 binance coins …',
#   'url': 'https://yro.slashdot.org/story/22/01/28/1822238/defi-platform-qubit-finance-begs-hacker-to-return-80-million-in-stolen-funds',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#   'publishedAt': '2022-01-28T23:23:00Z',
#   'content': "On Thursday, the DeFi platform said their protocol was exploited by a hacker who eventually stole 206,809 binance coins from Qubit's QBridge protocol, worth more than $80 million according to PeckShi… [+1407 chars]"},
#  {'source': {'id': None, 'name': 'Finbold.com'},
#   'author': None,
#   'title': 'Wormhole confirms all $320M in funds have been restored',
#   'description': 'Hackers stole $322 million from Solana after exploiting a Wormhole vulnerability, but the latest update suggests the funds have been restored.',
#   'url': 'https://finbold.com/wormhole-confirms-all-300-million-in-funds-have-been-restored/',
#   'urlToImage': 'https://finbold.com/wp-content/uploads/2022/02/Wormhole-confirms-all-320-million-in-funds-have-been-restored.jpg',
#   'publishedAt': '2022-02-03T18:19:33Z',
#   'content': 'After exploiting a Wormhole vulnerability, hackers stole around $322 million from Solana (SOL), but the interoperability protocol has recently updated its users that the funds have been restored.\r\nAc… [+1807 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Insider Inc.)',
#   'title': "Cathie Wood's Ark Invest expects ether to soar over 7,000% and hit a $20 trillion market cap by 2030",
#   'description': 'A note from the firm said ether will meet or surpass a $20 trillion market cap by 2030, adding that the price of one bitcoin could hit $1 million.',
#   'url': 'https://markets.businessinsider.com/news/currencies/ether-price-prediction-ark-invest-cathie-wood-bitcoin-crypto-2022-1',
#   'urlToImage': 'https://i.insider.com/61f2c334792e7300116be152?width=1200&format=jpeg',
#   'publishedAt': '2022-01-27T17:31:27Z',
#   'content': "Even as crypto markets face turbulence, Cathie Wood's Ark Invest is making a bullish call on the price of ether in a new report this week.\xa0\r\nThe second-largest cryptocurrency, according to Ark Invest… [+1478 chars]"},
#  {'source': {'id': None, 'name': 'Entrepreneur'},
#   'author': 'Entrepreneur Store',
#   'title': 'Explore Blockchain and Google Ops with this January Sale on E-Learning',
#   'description': "Learn today's trending technologies online.",
#   'url': 'https://www.entrepreneur.com/article/413161',
#   'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1642115843-Ent-GDevOps.jpeg',
#   'publishedAt': '2022-01-18T13:30:00Z',
#   'content': "These days, you've no doubt heard of the blockchain. The trending technology caught the world's attention in the form of cryptocurrency, but the blockchain has many uses today across many industries.… [+1950 chars]"},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'CRYPTOVERSE-Bitcoin squeezes smaller rivals to its crown - Reuters',
#   'description': 'Bitcoin is beginning to reassert its dominance over challengers to its cryptocurrency crown.',
#   'url': 'https://www.reuters.com/markets/europe/cryptoverse-bitcoin-squeezes-smaller-rivals-its-crown-2022-02-01/',
#   'urlToImage': 'https://www.reuters.com/resizer/trzf0WaGaNyLC7bG_gRXhD2h0Ag=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/SLSYKLM3IJPZNNH5EMCYLZA2F4.jpg',
#   'publishedAt': '2022-02-01T06:00:00Z',
#   'content': 'Feb 1 (Reuters) - Bitcoin is beginning to reassert its dominance over challengers to its cryptocurrency crown.\r\nThe original digital coin was assailed by thousands of new "altcoin" competitors in 202… [+3972 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Global crypto funds post sharp gains in 2021 -BarclayHedge - Reuters',
# ...
#   'urlToImage': 'https://api.time.com/wp-content/uploads/2022/01/B-1.jpg?quality=85&w=1024&h=628&crop=1',
#   'publishedAt': '2022-01-22T17:23:54Z',
#   'content': 'Bitcoin extended its decline on Saturday, and has shed more than 50% from its record high in November while adding further momentum to the meltdown in cryptocurrencies.\r\n“Margin positions being liqui… [+1539 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'prosen@insider.com (Phil Rosen)',
#   'title': '10 things before the opening bell',
#   'description': "Jeremy Grantham's warning about a stock market crash, inflation and investing concerns, and El Salvador's new crypto loans.",
#   'url': 'https://markets.businessinsider.com/news/stocks/10-things-before-the-opening-bell-january-24-2022-1',
#   'urlToImage': 'https://i.insider.com/61eb006ed265300018042c5f?width=1200&format=jpeg',
#   'publishedAt': '2022-01-24T11:25:49Z',
#   'content': "Welcome to 10 Things Before the Opening Bell.\r\nIf this was forwarded to you, sign up here. Plus, download Insider's app for news on the go click here for iOS andhere for Android.\r\nLet's jump in.\xa0\r\n1.… [+2823 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'prosen@insider.com (Phil Rosen)',
#   'title': '10 things before the opening bell',
#   'description': 'Buying the dip on tech stocks, a DAO with a trove of Bored Ape Yacht Club NFTs, and stocks to buy amid the sell-off.',
#   'url': 'https://markets.businessinsider.com/news/stocks/10-things-before-the-opening-bell-february-1-2022-1',
#   'urlToImage': 'https://i.insider.com/61f83900415c3f0018d3c44b?width=1200&format=jpeg',
#   'publishedAt': '2022-02-01T11:48:09Z',
#   'content': "Welcome to 10 Things Before the Opening Bell.\r\nIf this was forwarded to you, sign up here. Plus, download Insider's app for news on the go click here for iOS andhere for Android.\r\nHere we go.\xa0\r\n1. Bu… [+3186 chars]"},
#  {'source': {'id': None, 'name': 'Techmeme.com'},
#   'author': None,
#   'title': "OnlyFans launches NFT profile pictures minted on the Ethereum blockchain; creators' NFT profile pictures will show an Ethereum symbol to mark them as authentic (Elizabeth Culliford/Reuters)",
#   'description': "Elizabeth Culliford / Reuters:\nOnlyFans launches NFT profile pictures minted on the Ethereum blockchain; creators' NFT profile pictures will show an Ethereum symbol to mark them as authentic\xa0 —\xa0 (Reuters) - OnlyFans, an online subscription platform known for …",
#   'url': 'https://www.techmeme.com/220210/p35',
#   'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20220210&t=2&i=1590756020&r=LYNXMPEI1913M&w=800',
#   'publishedAt': '2022-02-10T21:55:01Z',
#   'content': 'CB Insights Newsletter\r\n724,948 subscribers get our free newsletter to stay a step ahead on technology trends, venture capital, startups, and the industries of tomorrow.'},
#  {'source': {'id': None, 'name': 'Techmeme.com'},
#   'author': None,
#   'title': "A look at the Ethereum Name Service DAO's vote to remove Brantly Millegan for expressing bigoted views, as token holders re-delegated their tokens away from him (Casey Newton/Platformer)",
#   'description': "Casey Newton / Platformer:\nA look at the Ethereum Name Service DAO's vote to remove Brantly Millegan for expressing bigoted views, as token holders re-delegated their tokens away from him\xa0 —\xa0 The public face of Ethereum Name Service did a bad tweet.\xa0 Does web…",
#   'url': 'https://www.techmeme.com/220211/p10',
#   'urlToImage': 'https://cdn.substack.com/image/fetch/w_1200,c_limit,f_jpg,q_auto:good,fl_progressive:steep/https%3A%2F%2Fbucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com%2Fpublic%2Fimages%2Fefa41af8-7f84-4ce6-b293-81eb5bf99a8b_7680x4320.jpeg',
#   'publishedAt': '2022-02-11T17:30:01Z',
#   'content': 'CB Insights Newsletter\r\n724,948 subscribers get our free newsletter to stay a step ahead on technology trends, venture capital, startups, and the industries of tomorrow.'},
#  {'source': {'id': None, 'name': 'Due.com'},
#   'author': 'Deanna Ritchie',
#   'title': 'What Could Halt Cryptocurrency Momentum?',
#   'description': 'Millions of investors, speculators, and crypto hobbyists have bought and sold cryptocurrency in the past decade or so, hoping that crypto would be both a powerful investment and a currency...',
#   'url': 'https://due.com/blog/cryptocurrency-momentum/',
#   'urlToImage': 'https://assets.entrepreneur.com/providers/due/hero-image-due-413159.jpeg',
#   'publishedAt': '2022-01-13T21:15:09Z',
#   'content': 'Millions of investors, speculators, and crypto hobbyists have bought and sold cryptocurrency in the past decade or so, hoping that crypto would be both a powerful investment and a currency of the fut… [+7409 chars]'},
#  {'source': {'id': None, 'name': 'ReadWrite'},
#   'author': 'Jordan Bishop',
#   'title': '5 Ways to Use NFTs to Boost Brand Awareness',
#   'description': 'NFTs are reshaping the internet and looking at digital assets and content such as blog posts, images, videos, audio files, and more. As a result, businesses worldwide are now diving into the NFT space to try and get that early adopter advantage and make the m…',
#   'url': 'https://readwrite.com/use-nfts-to-boost-brand-awareness/',
#   'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2022/01/Use-NFTs-to-Boost-Brand.jpg',
#   'publishedAt': '2022-02-10T22:00:11Z',
#   'content': 'NFTs are reshaping the internet and looking at digital assets and content such as blog posts, images, videos, audio files, and more. As a result, businesses worldwide are now diving into the NFT spac… [+8660 chars]'},
#  {'source': {'id': None, 'name': 'Tomtunguz.com'},
#   'author': None,
#   'title': 'How Much Money Is Flowing into Crypto?',
#   'description': 'How much money flows into crypto each month?\nThere’s the headline figure $1.7T which is the aggregate market cap of crypto. But how about the volumes of US dollars being exchanged into crypto each month? Sometimes this is called fund flows.\nI’ve learned calcu…',
#   'url': 'https://www.tomtunguz.com/how-much-money-flowing-into-crypto/',
#   'urlToImage': None,
#   'publishedAt': '2022-02-02T22:43:22Z',
#   'content': 'How much money flows into crypto each month?\r\nThere’s the headline figure $1.7T which is the aggregate market cap of crypto. But how about the volumes of US dollars being exchanged into crypto each m… [+1968 chars]'},
#  {'source': {'id': None, 'name': 'Techmeme.com'},
#   'author': None,
#   'title': 'Blockchain network Polygon, which serves as a support layer for Ethereum, raises $450M led by Sequoia Capital India at a $2B valuation (Ryan Browne/CNBC)',
#   'description': 'Ryan Browne / CNBC:\nBlockchain network Polygon, which serves as a support layer for Ethereum, raises $450M led by Sequoia Capital India at a $2B valuation\xa0 —\xa0 - Sequoia Capital India led a $450 million investment in Polygon, a blockchain network that serves a…',
#   'url': 'https://www.techmeme.com/220207/p10',
#   'urlToImage': 'https://image.cnbcfm.com/api/v1/image/107011789-1644217792954-gettyimages-1236413079-porzycki-altcoins211106_npHhN.jpeg?v=1644217869',
#   'publishedAt': '2022-02-07T14:50:15Z',
#   'content': 'CB Insights Newsletter\r\n724,948 subscribers get our free newsletter to stay a step ahead on technology trends, venture capital, startups, and the industries of tomorrow.'},
#  {'source': {'id': None, 'name': 'Techmeme.com'},
#   'author': None,
#   'title': 'Blockchain network Polygon, which serves as a support layer for Ethereum, raises $450M led by Sequoia Capital India; Polygon has a ~$13B market cap (Manish Singh/TechCrunch)',
#   'description': 'Manish Singh / TechCrunch:\nBlockchain network Polygon, which serves as a support layer for Ethereum, raises $450M led by Sequoia Capital India; Polygon has a ~$13B market cap\xa0 —\xa0 Ethereum scaling firm Polygon has raised $450 million in a new venture financing…',
#   'url': 'https://www.techmeme.com/220207/p12',
#   'urlToImage': 'https://techcrunch.com/wp-content/uploads/2018/04/gettyimages-623910272.jpg?w=533',
#   'publishedAt': '2022-02-07T15:22:48Z',
#   'content': 'CB Insights Newsletter\r\n724,948 subscribers get our free newsletter to stay a step ahead on technology trends, venture capital, startups, and the industries of tomorrow.'},
#  {'source': {'id': None, 'name': 'VentureBeat'},
#   'author': 'Olga Vorobyeva',
#   'title': 'Innovation will drive the success of NFT gaming, not profit or hype',
#   'description': '2022 is likely the year NFT gaming becomes mainstream. Innovation, not just in NFTs but in gameplay and mechanics, will be the driving force.',
#   'url': 'https://venturebeat.com/2022/01/25/innovation-will-drive-the-success-of-nft-gaming-not-profit-or-hype/',
#   'urlToImage': 'https://venturebeat.com/wp-content/uploads/2022/01/GettyImages-1353445926.jpg?w=1200&strip=all',
#   'publishedAt': '2022-01-25T21:20:00Z',
#   'content': 'Did you miss a session from the Future of Work Summit? Head over to our\xa0Future of Work Summit on-demand library\xa0to stream.\r\nThis article was contributed by Olga Vorobyeva, VOX Consulting.\r\nNonfungibl… [+9053 chars]'},
#  {'source': {'id': None, 'name': 'Techmeme.com'},
#   'author': None,
#   'title': 'Tether says it froze three Ethereum blockchain addresses containing $160M on a law enforcement request; Bloxy data shows Tether froze 563 addresses since 2017 (Helene Braun/CoinDesk)',
#   'description': 'Helene Braun / CoinDesk:\nTether says it froze three Ethereum blockchain addresses containing $160M on a law enforcement request; Bloxy data shows Tether froze 563 addresses since 2017\xa0 —\xa0 Stablecoin issuer Tether froze three Ethereum addresses on Thursday, ho…',
#   'url': 'https://www.techmeme.com/220114/p1',
#   'urlToImage': 'https://www.coindesk.com/resizer/6mKy47WKjgO_Y8k5oxtnEa0gylU=/cloudfront-us-east-1.images.arcpublishing.com/coindesk/YKCKRCEWHFDLFLBUT52JQNEUGQ.jpg',
#   'publishedAt': '2022-01-14T07:20:00Z',
#   'content': 'Big Technology— by Alex Kantrowitz\r\nRevealing the systems in the tech world that drive what we see in the headlines, focusing primarily on the tech giants: Amazon, Apple, Facebook, Google, and Micros… [+3 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Sherry Fairchok)',
#   'title': 'Twig and Responsible fundraise on the appeal of the circular economy',
#   'description': 'Two fintechs powering circularity and resale of fashion and luxury items pitch sustainability while also edging their users into a tokenized economy.',
#   'url': 'https://www.businessinsider.com/two-recommerce-fintechs-focused-on-sustainable-fashion-2022-1',
#   'urlToImage': 'https://i.insider.com/61e03c44dbf4c6001931d137?width=1200&format=jpeg',
#   'publishedAt': '2022-01-13T14:51:44Z',
#   'content': "The news:\xa0Two recommerce fintechs based in the British Isles impressed investors with pitches that promoted their circularity and sustainability. Both started off in fashionand couldn't have picked a… [+3877 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Jen Glantz)',
#   'title': "My husband told me to put my money in a crypto high interest account, but I'm glad I ignored his advice for 3 reasons",
#   'description': "Many people are on the cryptocurrency bandwagon, but you might want to think twice about putting your money in an account that's not FDIC insured.",
#   'url': 'https://www.businessinsider.com/personal-finance/reasons-why-didnt-put-money-crypto-high-interest-account-2022-1',
#   'urlToImage': 'https://i.insider.com/61eb3391d265300018044036?width=1200&format=jpeg',
#   'publishedAt': '2022-01-22T13:30:00Z',
#   'content': 'One of the biggest and best decisions my husband and I made when we got married last March was to keep the majority of our finances separate.\r\nWe have one joint checking account that stores money fro… [+3176 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Ben Gilbert)',
#   'title': "Elon Musk joked that McDonald's should accept Dogecoin. Here's why that doesn't make any sense.",
#   'description': '"I will eat a happy meal on TV if McDonald\'s accepts Dogecoin," Musk said on Tuesday morning. McDonald\'s doesn\'t accept any form of cryptocurrency.',
#   'url': 'https://www.businessinsider.com/why-almost-no-retailers-accept-crypto-2022-1',
#   'urlToImage': 'https://i.insider.com/61a7f0b80ed48c0019e54b7c?width=1200&format=jpeg',
#   'publishedAt': '2022-01-26T15:35:21Z',
#   'content': 'Billionaire Tesla CEO Elon Musk is willing to put his money where his mouth is: "I will eat a happy meal on TV if McDonald\'s accepts dogecoin," he said on Tuesday morning.\r\nMusk owns undisclosed amou… [+3364 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'ilee@insider.com (Isabelle Lee)',
#   'title': 'Nasdaq falls nearly 3% as US stocks plummet on interest rate worries',
#   'description': 'The Nasdaq plunged Tuesday, dragged by mega-cap tech giants as the&nbsp;10-year Treasury yield rose to 1.87% &mdash; its highest level since January 2020.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-news-nasdaq-tech-stocks-interest-rates-fed-us-2022-1',
#   'urlToImage': 'https://images2.markets.businessinsider.com/6182819023745d001824cc35?format=jpeg',
#   'publishedAt': '2022-01-18T21:20:32Z',
#   'content': 'Traders work on the floor of the New York Stock Exchange (NYSE) on March 20, 2020 in New York City.Photo by Spencer Platt/Getty Images\r\nUS stocks plunged on Tuesday as Treasury yields jumped on inves… [+2871 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Sherry Fairchok)',
#   'title': "Google's forming a blockchain unit and looking to partner on crypto",
#   'description': 'Google\'s president of commerce said the company will team up with providers of "a wider range of financial services, including cryptocurrencies.',
#   'url': 'https://www.businessinsider.com/google-is-creating-blockchain-next-gen-computing-unit-2022-1',
#   'urlToImage': 'https://i.insider.com/61b9471b0a4bcd0018736cc6?width=1200&format=jpeg',
#   'publishedAt': '2022-01-24T14:52:00Z',
#   'content': 'The news:\xa0Google\xa0is creating a new unit dedicated to "blockchain and other next-gen distributed computing and data storage technologies," according to a leaked email\xa0obtained\r\n\xa0by Bloomberg.\r\nInsider… [+3345 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Will Paige)',
#   'title': "Twitter aims for edge in Big Tech's crypto contest with OpenNode investment",
#   'description': "Twitter invested an undisclosed sum in OpenNode's $20 million funding round that valued the Bitcoin payments provider at $220 million.",
#   'url': 'https://www.businessinsider.com/twitter-invests-in-opennode-20-million-funding-round-2022-2',
#   'urlToImage': 'https://i.insider.com/62067cd1e2fe3c0019ea2971?width=1200&format=jpeg',
#   'publishedAt': '2022-02-11T15:12:54Z',
#   'content': "The news:\xa0Tech heavyweight\xa0Twitter\xa0invested an undisclosed sum in\xa0OpenNode's $20 million funding round\xa0that valued the Bitcoin payments provider at $220 million, per CoinDesk.\r\nInsider Intelligence\r\n… [+2696 chars]"},
#  {'source': {'id': None, 'name': 'Motley Fool'},
#   'author': 'newsfeedback@fool.com (Katie Brockman)',
#   'title': 'Ethereum: Buy the Dip?',
#   'description': 'Ethereum seems to be rebounding. Is now the time to buy?',
#   'url': 'https://www.fool.com/investing/2022/02/11/ethereum-buy-the-dip/',
#   'urlToImage': 'https://g.foolcdn.com/editorial/images/665421/person-looking-at-a-tablet.jpg',
#   'publishedAt': '2022-02-11T10:45:00Z',
#   'content': 'The last few months have been rough for cryptocurrency, as the majority of cryptos have watched their prices take a nosedive. After reaching an all-time high in mid-November, the price of Ethereum(CR… [+3003 chars]'}]

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-02-09  Even if you arent paying attention to Bitcoin ...    0.5859
# 1  2022-01-12  When Denis Rusinovich set up cryptocurrency mi...    0.0000
# 2  2022-01-25  El Salvador introduced Bitcoin as a legal tend...    0.3182
# 3  2022-01-14  Were officially building an open Bitcoin minin...   -0.4404
# 4  2022-01-27  Israeli national Tal Prihar pled guilty to rou...   -0.3182
#
#    positive  negative  neutral
# 0     0.124     0.000    0.876
# 1     0.000     0.000    1.000
# 2     0.105     0.000    0.895
# 3     0.000     0.083    0.917
# 4     0.045     0.084    0.871

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-01-20  In a new blog post the company said that 4,836...    0.0000
# 1  2022-01-19  Hackers who made off with roughly $15 million ...    0.0000
# 2  2022-01-20  On some level, the new mayor is simply employi...    0.1779
# 3  2022-01-21  Back in September\r\n, Robinhood announced pla...    0.0772
# 4  2022-02-10  If people who buy cryptocurrencies intended on...   -0.2023
#
#    positive  negative  neutral
# 0     0.000     0.000    1.000
# 1     0.000     0.000    1.000
# 2     0.052     0.000    0.948
# 3     0.038     0.000    0.962
# 4     0.039     0.062    0.899

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.073527    0.069430    0.047950    0.882590
# std      0.428141    0.062734    0.064763    0.083741
# min     -0.817600    0.000000    0.000000    0.662000
# 25%     -0.288875    0.000000    0.000000    0.831000
# 50%      0.064400    0.070000    0.000000    0.895000
# 75%      0.445000    0.112750    0.088000    0.937250
# max      0.834100    0.234000    0.258000    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.225761    0.079040    0.023070    0.897900
# std      0.370673    0.073744    0.041149    0.081804
# min     -0.709600    0.000000    0.000000    0.716000
# 25%      0.000000    0.000000    0.000000    0.842000
# 50%      0.190100    0.066000    0.000000    0.904500
# 75%      0.510600    0.129250    0.046000    0.959000
# max      0.880700    0.265000    0.174000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    # Remove the punctuation
    regex = re.compile("[^a-zA-Z0-9 ]")
    re_clean = regex.sub('', text)
    
    # Create a list of the words
    words = word_tokenize(re_clean.lower())
    
    # Remove the stop words
    words = [word for word in words if word not in sw]
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    
    # Convert the words to lowercase
    words = [word for word in words if word not in sw]

    # Remove the stop words
    return lem

# %%
# Create a new tokens column for Bitcoin
bitcoin_df['tokens'] = bitcoin_df['text'].apply(tokenizer)
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-02-09  Even if you arent paying attention to Bitcoin ...    0.5859
# 1  2022-01-12  When Denis Rusinovich set up cryptocurrency mi...    0.0000
# 2  2022-01-25  El Salvador introduced Bitcoin as a legal tend...    0.3182
# 3  2022-01-14  Were officially building an open Bitcoin minin...   -0.4404
# 4  2022-01-27  Israeli national Tal Prihar pled guilty to rou...   -0.3182
#
#    positive  negative  neutral  \
# 0     0.124     0.000    0.876
# 1     0.000     0.000    1.000
# 2     0.105     0.000    0.895
# 3     0.000     0.083    0.917
# 4     0.045     0.084    0.871
#
#                                               tokens
# 0  [even, arent, paying, attention, bitcoin, cryp...
# 1  [denis, rusinovich, set, cryptocurrency, minin...
# 2  [el, salvador, introduced, bitcoin, legal, ten...
# 3  [officially, building, open, bitcoin, mining, ...
# 4  [israeli, national, tal, prihar, pled, guilty,...

# %%
# Create a new tokens column for Ethereum
ethereum_df['tokens'] = ethereum_df['text'].apply(tokenizer)
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-01-20  In a new blog post the company said that 4,836...    0.0000
# 1  2022-01-19  Hackers who made off with roughly $15 million ...    0.0000
# 2  2022-01-20  On some level, the new mayor is simply employi...    0.1779
# 3  2022-01-21  Back in September\r\n, Robinhood announced pla...    0.0772
# 4  2022-02-10  If people who buy cryptocurrencies intended on...   -0.2023
#
#    positive  negative  neutral  \
# 0     0.000     0.000    1.000
# 1     0.000     0.000    1.000
# 2     0.052     0.000    0.948
# 3     0.038     0.000    0.962
# 4     0.039     0.062    0.899
#
#                                               tokens
# 0  [new, blog, post, company, said, 4836, eth, 44...
# 1  [hacker, made, roughly, 15, million, ethereum,...
# 2  [level, new, mayor, simply, employing, ageold,...
# 3  [back, september, robinhood, announced, plan, ...
# 4  [people, buy, cryptocurrencies, intended, hold...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def get_token(df):
    tokens = []
    for token in df['tokens']:
        tokens.extend(token)
    return tokens

btc_tokens = get_token(bitcoin_df)
eth_tokens = get_token(ethereum_df)

# %%
# Generate the Bitcoin N-grams where N=2
def bigram_counter(tokens, N=2):
    words_count = dict(Counter(ngrams(tokens, n=N)))
    return words_count

bigram_btc = bigram_counter(btc_tokens, 2)

# %%
# Generate the Ethereum N-grams where N=2
bigram_eth = bigram_counter(eth_tokens, 2)

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
top_10_token_btc = token_count(btc_tokens)
top_10_token_btc
# Out:
# [('char', 99),
#  ('bitcoin', 65),
#  ('reuters', 31),
#  ('cryptocurrency', 28),
#  ('new', 21),
#  ('u', 15),
#  ('jan', 15),
#  ('said', 14),
#  ('crypto', 14),
#  ('company', 13)]

# %%
# Use token_count to get the top 10 words for Ethereum
top_10_token_eth = token_count(eth_tokens)
top_10_token_eth
# Out:
# [('char', 94),
#  ('cryptocurrency', 26),
#  ('ethereum', 21),
#  ('new', 20),
#  ('bitcoin', 20),
#  ('digital', 16),
#  ('million', 13),
#  ('blockchain', 13),
#  ('reuters', 13),
#  ('crypto', 11)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(btc_tokens))
plt.imshow(wc)
plt.title(label="Bitcoin Word Cloud", fontdict={'fontsize': 35, 'fontweight': 'bold'})
# Out:
# Text(0.5, 1.0, 'Bitcoin Word Cloud')

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(' '.join(eth_tokens))
plt.imshow(wc)
plt.title(label="Ethereum Word Cloud", fontdict={'fontsize': 35, 'fontweight': 'bold'})
# Out:
# Text(0.5, 1.0, 'Ethereum Word Cloud')

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\users\jakek\anaconda3\lib\site-packages (from en-core-web-sm==3.2.0) (3.2.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: jinja2 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: setuptools in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.0.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.20.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.26.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\jakek\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jakek\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\jakek\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jakek\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jakek\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jakek\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jakek\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jakek\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.4)
# Requirement already satisfied: colorama in c:\users\jakek\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\jakek\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jakek\anaconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_content = ' '.join(bitcoin_df['text'])

# %%
# Run the NER processor on all of the text
doc_btc = nlp(btc_content)

# Add a title to the document
doc_btc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(doc_btc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Even if you arent paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with the total value of the market tumbling from a high of $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  tr… [+4782 chars] When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Denis Rusinovich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  set up cryptocurrency mining company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maveric Group
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kazakhstan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , he thought he had hit the jackpot. Next door to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the country had everything a Bitcoin … [+4140 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  introduced Bitcoin as a legal tender alongside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . | Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The International Monetary Fund’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  executive board has recommended
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  … [+2691 chars] Were officially building an open
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Photo by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Raedle/Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Block, the payment company formerly known as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Square
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , is working on building an open
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  mining system, it… [+2078 chars]
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israeli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  national
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tal Prihar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Illustration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <sp

# %%
# List all Entities
for ent in doc_btc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# last week DATE
# 3 MONEY
# Denis Rusinovich PERSON
# Maveric Group ORG
# Kazakhstan GPE
# 2017 DATE
# China GPE
# Russia GPE
# El Salvador GPE
# US GPE
# 2021 DATE
# Alex Castro PERSON
# Verge ORG
# The International Monetary Fund’s ORG
# El ORG
# Bitcoin PERSON
# Joe Raedle/Getty Images PERSON
# Square FAC
# Bitcoin PERSON
# Israeli NORP
# Tal Prihar PERSON
# Illustration ORG
# Alex Castro PERSON
# Verge ORG
# two-year DATE
# 4,836 CARDINAL
# ETH ORG
# 443 CARDINAL
# Alex Castro PERSON
# Verge ORG
# the early hours TIME
# Thursday DATE
# morning TIME
# Netflix ORG
# about one CARDINAL
# Ilya Lichtenstein PERSON
# this week DATE
# Saturday DATE
# more than 50% PERCENT
# November DATE
# more than $ MONEY
# Jack Dorsey PERSON
# Twitter PRODUCT
# first ORDINAL
# October last year DATE
# the "Giga Texas ORG
# Elon Musk PERSON
# Friday DATE
# Fintech ORG
# New York City GPE
# British NORP
# Richard ODell PERSON
# house ORG
# October DATE
# Poulde GPE
# Russia GPE
# Thursday DATE
# Russian NORP
# the last five years DATE
# about 25,000 CARDINAL
# Lichtensteins PERSON
# Bitcoin PERSON
# El Salvador GPE
# US GPE
# The International Monetary Fund ORG
# El Salvador GPE
# Reuters ORG
# Jan 26 DATE
# Reuters ORG
# The U.S. Securities and Exchange Commission ORG
# Thursday DATE
# ETF ORG
# Fidelitys Wise Origin Bitcoin ORG
# +202 GPE
# Jack Dorsey PERSON
# June DATE
# Joe Raedle/Getty Images PERSON
# one CARDINAL
# Tuesday DATE
# $4.5 billion MONEY
# September DATE
# Robinhood ORG
# one CARDINAL
# 2020 DATE
# Crypto.com ORG
# about $34 million MONEY
# Monday DATE
# One CARDINAL
# the European Unions ORG
# European Securities ORG
# Feb 1 DATE
# Reuters ORG
# thousands CARDINAL
# 202 CARDINAL
# Feb 4 DATE
# Reuters ORG
# 8.82% PERCENT
# 40,611.4 MONEY
# 2202 DATE
# Friday DATE
# 3,291.29 MONEY
# Bitcoin PERSON
# 23.2% PERCENT
# Bitcoin PERSON
# January 8, 2021 DATE
# REUTERS ORG
# Dado Ruvic/File PhotoJan PERSON
# 21 CARDINAL
# Reuters ORG
# 9.28% PERCENT
# 36 MONEY
# January 24, 2022 - DATE
# Ponzi ORG
# Elon Musk PERSON
# mid-May DATE
# Spain GPE
# more than 100,000 CARDINAL
# Trump White House ORG
# Anthony Scaramucci PERSON
# AP Photo/Pablo Martinez Monsivais ORG
# File ORG
# SkyBridge Capital ORG
# Anthony Scaramucci PERSON
# Bloombergs Lorcan Roche Kelly ORG
# first ORDINAL
# the 21st cen DATE
# almost half CARDINAL
# November DATE
# Bitcoin PERSON
# LONDON GPE
# Jan 24 DATE
# Reuters ORG
# over 7% PERCENT
# Monday DATE
# six months DATE
# Russian NORP
# Ukraine GPE
# Feb 8 DATE
# Reuters ORG
# 2022 DATE
# NEW YORK GPE
# Feb 11 DATE
# Reuters ORG
# Federal Reserve ORG
# the U.S. Securities and Exchange Commission ORG
# SEC ORG
# Washington GPE
# D.C. GPE
# U.S. GPE
# May 12, 2021 DATE
# May 12, 2021 DATE
# REUTERS ORG
# Andrew Kelly PERSON
# Intercon ORG
# LONDON GPE
# NEW YORK GPE
# Jan 24 DATE
# Reuters ORG
# six months DATE
# Monday DATE
# Russian NORP
# Ukraine GPE
# Feb 11 DATE
# Reuters ORG
# Intel Corp ORG
# Friday DATE
# Fed ORG
# LONDON GPE
# Jan 14 DATE
# Reuters ORG
# Kazakhstan GPE
# Jan 25 DATE
# Reuters ORG
# 13 CARDINAL
# this year DATE
# U.S. Justice Department ORG
# Tuesday DATE
# $3.6 billion MONEY
# 2016 DATE
# NEW YORK GPE
# Feb 9 DATE
# Tuesday DATE
# Ilya Dutch Lich ORG
# El Salvador GPE
# Jan 25 DATE
# Reuters ORG
# El Salvador GPE
# Jan 17 DATE
# Reuters ORG
# 2022 DATE
# December DATE
# +3835 ORG
# A year ago DATE
# February 8 DATE
# $1.5 billion MONEY
# three CARDINAL
# one CARDINAL
# Tesla ORG
# $20 million MONEY
# $220 million MONEY
# CoinDesk ORG
# Intelligence ORG
# 2021 DATE
# Michael Saylor PERSON
# MicroStrategyJoe Raedle/Getty Images ORG
# MicroStrategy ORG
# two-day DATE
# 30% PERCENT
# Monday DATE
# SEC ORG
# MicroStrategy ORG
# $146.6 million MONEY
# the fourth quarter of 2021 DATE
# six-fold CARDINAL
# the same period last year DATE
# Treasury ORG
# Alejandro Zelaya PERSON
# Zelaya PERSON
# Bitcoin PERSON
# +607 ORG
# the past 12 years DATE
# Anthony Welch PERSON
# Theresa PERSON
# Robinson Crusoe ORG
# South Pacific LOC
# Welch ORG
# British NORP
# Reuters ORG
# NEW YORK GPE
# Jan 27 DATE
# Reuters ORG
# the International Monetary Fund ORG
# El Salvador GPE
# $800 million MONEY
# El Salvador's GPE
# $10 million MONEY
# this quarter DATE
# CoinDesk ORG
# 2009 DATE
# first ORDINAL
# NEW YORK GPE
# Jan 14 DATE
# Reuters ORG
# last year DATE
# Thomson Reuters Foundation ORG
# The International Monetary Fund ORG
# El Salvador GPE
# Jan 13 DATE
# Reuters ORG
# BTCS Inc ORG
# Thursday DATE
# four-day DATE
# NEW YORK GPE
# Jan 12 DATE
# Reuters ORG
# Brazilian NORP
# Latin America's LOC
# Mercado Bitcoin PERSON
# Wednesday DATE
# NEW YORK GPE
# LONDON GPE
# Jan 24 DATE
# Reuters ORG
# the day on DATE
# Monday DATE
# six months DATE
# Russian NORP
# Recasts NORP
# NEW YORK GPE
# LONDON GPE
# Jan 24 DATE
# Reuters ORG
# the day on DATE
# Monday DATE
# HONG KONG GPE
# Jan 24 DATE
# Reuters ORG
# Monday DATE
# the U.S. Federal Reserve's ORG
# January DATE
# later this week DATE
# six-month DATE
# Feb 3 DATE
# Reuters ORG
# last year's DATE
# Thursday DATE
# LONDON GPE
# Feb 8 DATE
# Reuters ORG
# Ukrainian GPE
# 20 CARDINAL
# Mike Novogratz PERSON
# $3.6 billion MONEY
# 2016 DATE
# Bitfinex ORG
# today DATE
# Jack Dorsey PERSON
# Bitcoin Legal Defense Fund ORG
# Intelligence ORG
# Crypto PERSON
# Dorsey ORG
# Tuesday DATE
# Meta ORG
# Diem ORG
# Libra NORP
# this week DATE
# Dorsey PERSON
# Meta PERSON
# ZDNet ORG
# Steven Vaughan-Nichols PERSON
# Linus Torvalds ORG
# Satoshi Nakamoto PERSON
# first ORDINAL
# roughly $15 million MONEY
# Crypto.com ORG
# Tornado Cash PERSON
# Jack Dorsey PERSON
# the U.S. House of Representatives Energy and Commerce Committee ORG
# Social Media's Role WORK_OF_ART
# ATM ORG
# Los Angeles GPE
# The Justice Department ORG
# New York GPE
# billions of dollars MONEY
# New York City GPE
# Eric Adams PERSON
# Bronx GPE
# New York City GPE
# New York GPE
# U.S. GPE
# January 3, 2022 DATE
# REUTERS ORG
# Carlo Allegri/File PERSON
# Elon Musk PERSON
# McDonald's ORG
# Tuesday DATE
# morning TIME
# Musk PERSON
# Cathie Wood's PERSON
# Ark Invest PERSON
# this week DATE
# second ORDINAL
# Ark Invest PERSON
# MOSCOW GPE
# Jan 20 DATE
# Reuters ORG
# Russia GPE
# Thursday DATE
# Russian NORP
# 2024 DATE
# Thailand GPE
# WASHINGTON GPE
# Feb 8 DATE
# Reuters ORG
# UBS ORG
# winter DATE
# Marvin Recinos/Getty Images PERSON
# winter DATE
# Bloomberg TV ORG
# Crypto.com ORG
# Kris Marszalek PERSON
# 400 CARDINAL
# Friday DATE
# morning TIME
# Dogecoin ORG
# more than 15% PERCENT
# Tesla ORG
# CNBC ORG
# US GPE
# 3.6bn MONEY
# 2016 CARDINAL
# El Salvadors ORG
# Nayib Bukeles PERSON
# six months DATE
# Monday DATE
# Russian NORP
# Ukraine GPE
# WASHINGTON GPE
# Feb 8 DATE
# Reuters ORG
# FBI ORG
# Tuesday DATE
# morning TIME
# 2016 DATE
# Bitfinex ORG
# NEW YORK GPE
# Jan 21 DATE
# Reuters ORG
# U.S. GPE
# the latest week DATE
# mid-September 2021 DATE
# Reuters ORG
# U.S GPE
# Knox PERSON
# Quantum ORG
# around one million CARDINAL
# today DATE
# US GPE
# Monday DATE
# the previous week DATE
# Thursday DATE
# above $42,000 MONEY
# Anna Moneymaker/GettyOn PERSON
# Sept. 4, 2017 DATE
# Joel Greenberg PERSON
# Matt Gaetz PERSON
# NBC Sports ORG
# Buccaneers PERSON
# Tom Brady PERSON
# June 1 DATE
# Brady PERSON
# Hundreds of thousands CARDINAL
# every day DATE
# Bitcoin PERSON

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_content = ' '.join(ethereum_df['text'])

# %%
# Run the NER processor on all of the text
doc_eth = nlp(eth_content)

# Add a title to the document
doc_eth.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(doc_eth, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In a new blog post the company said that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,836
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     443
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>In a blog post published in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the early hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , cryptocurrency… [+2004 chars] Hackers who made off with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in ethereum from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are attempting to launder the funds through a so-called ethereum mixer, known as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tornado Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , according to a new report from… [+3891 chars] On some level, the new mayor is simply employing an age-old political strategy: making overtures to the business community.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fintech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a growing field in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and blockchain-based companies… [+1562 chars] Back in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robinhood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availa… [+1069 chars] If people who buy cryptocurrencies intended only to hold on to them as speculative investments, there'd be no real need for crypto wallets. Exchanges and online brokerages that convert dollars to, sa… [+3031 chars] This enables an L1 platform to bootstrap its national economy over time through a flywheel between financial speculation around its native token and actual building of applications and activities in … [+4057 chars] Trading platform
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  lost
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about $34 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of cryptocurrency in a hack on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>--
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saul Alinsky Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a digital platform that runs on blockchain technology. It's most commonly known for its smart contract functionality and native cryptocurrency, ether. The broader purpose of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vitalik Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the co-founder and inventor of
# <mark class="entit

# %%
# List all Entities
for ent in doc_eth.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# 4,836 CARDINAL
# ETH ORG
# 443 CARDINAL
# Alex Castro PERSON
# Verge ORG
# the early hours TIME
# Thursday DATE
# morning TIME
# roughly $15 million MONEY
# Crypto.com ORG
# Tornado Cash PERSON
# Fintech ORG
# New York City GPE
# September DATE
# Robinhood ORG
# Crypto.com ORG
# about $34 million MONEY
# Monday DATE
# Saul Alinsky Ethereum ORG
# Ethereum ORG
# Vitalik Buterin PERSON
# Ethereum ORG
# Feb 7 DATE
# Reuters ORG
# Monday DATE
# $450 million MONEY
# Sequoia Capital India ORG
# OPEN ORG
# second ORDINAL
# OPEN ORG
# second ORDINAL
# nearly $324 million MONEY
# Getty Images PERSON
# more than $324 million MONEY
# Wormhole PERSON
# 120,000 CARDINAL
# wEth ORG
# Ethereum ORG
# nearly $324 million MONEY
# Getty Images PERSON
# more than $324 million MONEY
# Wormhole PERSON
# Bloomberg TV ORG
# Crypto.com ORG
# Kris Marszalek PERSON
# 400 CARDINAL
# British NORP
# Richard ODell PERSON
# house ORG
# October DATE
# Poulde GPE
# Feb 4 DATE
# Reuters ORG
# 8.82% PERCENT
# 40,611.4 MONEY
# 2202 DATE
# Friday DATE
# 3,291.29 MONEY
# Bitcoin PERSON
# 23.2% PERCENT
# TIME ORG
# weekly DATE
# Vita ORG
# New York City GPE
# Eric Adams PERSON
# first ORDINAL
# Friday DATE
# Bitcoin and Ethereum ORG
# Coinbase Global Inc. ORG
# U.S. GPE
# Feb 3 DATE
# Reuters ORG
# NFT ORG
# later this year DATE
# Reuters ORG
# Thursday DATE
# UK GPE
# Bitcoin PERSON
# January 8, 2021 DATE
# REUTERS ORG
# Dado Ruvic/File PhotoJan PERSON
# 21 CARDINAL
# Reuters ORG
# 9.28% PERCENT
# 36 MONEY
# Bitcoin, Ethereum ORG
# DogeCoin ORG
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration PERSON
# MOSCOW GPE
# Jan DATE
# today DATE
# Fed ORG
# New York City GPE
# Eric Adams PERSON
# Bronx GPE
# New York City GPE
# New York GPE
# U.S. GPE
# January 3, 2022 DATE
# REUTERS ORG
# Carlo Allegri/File PERSON
# 2017 DATE
# +5776 ORG
# Twitter PRODUCT
# Wash PERSON
# NFT ORG
# NFT ORG
# analy GPE
# +922 PERSON
# the year DATE
# Monday DATE
# meme GPE
# token ORG
# 51.12% PERCENT
# 24 hours TIME
# 0.00003492 MONEY
# 1:11 DATE
# Jan 20 DATE
# Reuters ORG
# 1,000 CARDINAL
# Reuters ORG
# $207 million MONEY
# Blockdaemon GPE
# $3.25 billion MONEY
# Wednesday DATE
# Feb 11 DATE
# Reuters ORG
# Intel Corp ORG
# Friday DATE
# Ethereum ORG
# Solana PERSON
# almost half CARDINAL
# November DATE
# Bitcoin PERSON
# January 2022 DATE
# India GPE
# one CARDINAL
# 2022 DATE
# Ethereum ORG
# second ORDINAL
# Bitcoin PERSON
# Thousands CARDINAL
# every day DATE
# weeks DATE
# at least one CARDINAL
# January 1st DATE
# 2022 DATE
# the past day DATE
# Ash Barty PERSON
# Rafael Nadal PERSON
# Melbourne GPE
# NFT ORG
# the Friendship Bridge PRODUCT
# North Korean NORP
# Sinuiju GPE
# Chinese NORP
# Dandong GPE
# China GPE
# Liaoning province GPE
# January 9 DATE
# KHANNA/AFP ORG
# Gucci PERSON
# Italian NORP
# Crypto.com ORG
# Singapore GPE
# nearly $15m MONEY
# Ethereum GPE
# the weekend DATE
# overnight TIME
# more than US$326 million MONEY
# A$457.7 million MONEY
# Ethereum GPE
# two CARDINAL
# Thursday DATE
# DeFi GPE
# Qubit ORG
# more than $80 million MONEY
# PeckShi PRODUCT
# Wormhole PERSON
# $322 million MONEY
# Solana PERSON
# Ac ORG
# Cathie Wood's PERSON
# Ark Invest PERSON
# this week DATE
# second ORDINAL
# Ark Invest PERSON
# These days DATE
# today DATE
# Feb 1 DATE
# Reuters ORG
# thousands CARDINAL
# 202 CARDINAL
# NEW YORK GPE
# Jan 14 DATE
# Reuters ORG
# last year DATE
# TORONTO ORG
# Feb 8 DATE
# Reuters ORG
# Canada GPE
# TMX Group ORG
# first ORDINAL
# 2022 DATE
# April 26-28th DATE
# Dapper Labs PERSON
# Jamie Zawinski PERSON
# Whe ORG
# Friday DATE
# months DATE
# 35,422 MONEY
# Friday DATE
# Coinbase PERSON
# the first week of the year DATE
# 2022 DATE
# one CARDINAL
# GenZeroes ORG
# John Terry PERSON
# Premier League ORG
# NFT ORG
# Twitter PRODUCT
# Premier L ORG
# Ethereum PERSON
# registrar info ORG
# roughly $200k MONEY
# India GPE
# Tuesday DATE
# US GPE
# Tuesday DATE
# January DATE
# the day before DATE
# Europe LOC
# Swiss NORP
# February 4, 2022 DATE
# the last few years DATE
# Riot Games PERSON
# Valorant PERSON
# one CARDINAL
# Alex Kantrowitz PERSON
# Amazon ORG
# Apple ORG
# Micros ORG
# Founded PERSON
# 1972 DATE
# Atari ORG
# 50th anniversary this year DATE
# Molly White PERSON
# Wikipedia ORG
# 2006 DATE
# Arbitration Committee ORG
# Wikipedia ORG
# Knox PERSON
# American Express ORG
# American Express ORG
# Intelligence ORG
# UK GPE
# NFT ORG
# the month of January DATE
# NFT ORG
# Ethereum ORG
# $3.5 billion MONEY
# TORONTO GPE
# Jan 31 DATE
# Reuters ORG
# Canadian NORP
# Jan 17 DATE
# Reuters ORG
# 2022 DATE
# December DATE
# +3835 ORG
# 3080 CARDINAL
# Uefa GPE
# NFT ORG
# John Terry PERSON
# English LANGUAGE
# The Color Museum ORG
# NFT ORG
# Blockchain LOC
# Saturday DATE
# more than 50% PERCENT
# November DATE
# 10 CARDINAL
# the Opening Bell ORG
# Insider PERSON
# Android ORG
# 10 CARDINAL
# the Opening Bell ORG
# Insider PERSON
# Android ORG
# +3186 ORG
# 724,948 CARDINAL
# tomorrow DATE
# Insights Newsletter ORG
# 724,948 CARDINAL
# tomorrow DATE
# Millions CARDINAL
# the past decade DATE
# NFT ORG
# each month DATE
# 1.7 MONEY
# US GPE
# 724,948 CARDINAL
# tomorrow DATE
# Insights Newsletter ORG
# 724,948 CARDINAL
# tomorrow DATE
# the Future of Work Summit ORG
# Olga Vorobyeva PERSON
# VOX Consulting ORG
# Nonfungibl PERSON
# Alex Kantrowitz PERSON
# Amazon ORG
# Apple ORG
# Micros ORG
# Two CARDINAL
# British NORP
# last March DATE
# one CARDINAL
# +3176 CARDINAL
# Elon Musk PERSON
# McDonald's ORG
# Tuesday DATE
# morning TIME
# Musk PERSON
# the New York Stock Exchange ORG
# NYSE ORG
# March 20, 2020 DATE
# New York City GPE
# Spencer Platt/Getty Images PERSON
# US GPE
# Tuesday DATE
# Treasury ORG
# Bloomberg ORG
# $20 million MONEY
# $220 million MONEY
# CoinDesk ORG
# Intelligence ORG
# The last few months DATE
# mid-November DATE
# Ethereum(CR GPE

# %% [markdown]
# ---
